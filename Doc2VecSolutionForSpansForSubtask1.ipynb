# %% [markdown]
# ###  Load Dataset

# %%
from datasets import load_dataset

split = "train"
cache_dir = "./data_cache_doc2vec_solution_spans_notebook"

dialogue_dataset = load_dataset(
    "doc2dial",
    name="dialogue_domain",
    split=split,
    ignore_verifications=True,
    cache_dir=cache_dir,
)

document_dataset = load_dataset(
    "doc2dial",
    name="document_domain",
    split=split,
    ignore_verifications=True,
    cache_dir=cache_dir,
)

rc_dataset = load_dataset(
    "doc2dial",
    name="doc2dial_rc",
    split=split,
    ignore_verifications=True,
    cache_dir=cache_dir,
)
# Out:
# Downloading and preparing dataset doc2dial/dialogue_domain (download: 5.61 MiB, generated: 7.86 MiB, post-processed: Unknown size, total: 13.47 MiB) to ./data_cache_doc2vec_solution_spans_notebook/doc2dial/dialogue_domain/1.0.1/765cb4d9af421b599d910080fd61b4a43440c1232693876470ef3245daa5fa4c...
# Downloading:   0%|          | 0.00/5.88M [00:00<?, ?B/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset doc2dial downloaded and prepared to ./data_cache_doc2vec_solution_spans_notebook/doc2dial/dialogue_domain/1.0.1/765cb4d9af421b599d910080fd61b4a43440c1232693876470ef3245daa5fa4c. Subsequent calls will reuse this data.
# Downloading and preparing dataset doc2dial/document_domain (download: 5.61 MiB, generated: 195.38 MiB, post-processed: Unknown size, total: 200.99 MiB) to ./data_cache_doc2vec_solution_spans_notebook/doc2dial/document_domain/1.0.1/765cb4d9af421b599d910080fd61b4a43440c1232693876470ef3245daa5fa4c...
# 0 examples [00:00, ? examples/s]
# Dataset doc2dial downloaded and prepared to ./data_cache_doc2vec_solution_spans_notebook/doc2dial/document_domain/1.0.1/765cb4d9af421b599d910080fd61b4a43440c1232693876470ef3245daa5fa4c. Subsequent calls will reuse this data.
# Downloading and preparing dataset doc2dial/doc2dial_rc (download: 5.61 MiB, generated: 131.12 MiB, post-processed: Unknown size, total: 136.72 MiB) to ./data_cache_doc2vec_solution_spans_notebook/doc2dial/doc2dial_rc/1.0.1/765cb4d9af421b599d910080fd61b4a43440c1232693876470ef3245daa5fa4c...
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset doc2dial downloaded and prepared to ./data_cache_doc2vec_solution_spans_notebook/doc2dial/doc2dial_rc/1.0.1/765cb4d9af421b599d910080fd61b4a43440c1232693876470ef3245daa5fa4c. Subsequent calls will reuse this data.

# %% [markdown]
# # Train a model for each document

# %% [markdown]
# ### Preprocessing

# %%
import pandas as pd

document_full_df = pd.DataFrame(data=document_dataset)

# key=span_id, value=text
def span_dict_for_doc(doc_id):
    #use pandas as way faster
    document = document_full_df.loc[document_full_df['doc_id'] == doc_id]
    spans_dict = {}
    for span in document['spans'].iloc[0]:
        spans_dict[span['id_sp']]=span['text_sp']

    return spans_dict

# %%
from gensim.utils import simple_preprocess
#Getting a list of spans per grounding document !!!! Language confusion: spans are the documents in gensim land and the list of spans (aka the whole document) is the corpora in gensim

#I only want to use documents from the document datasets that have dialogues (which not all have)
unique_doc_ids = list(set(dialogue_dataset['doc_id']))

#extract all the span texts for that doc id,
#!!!Index drama. For list index starts with 0, for spans index starts with 1, use dict to keep the sp_id and doc_id
#key=doc_id, value=span dict


raw_training_text_per_doc = {}
for doc_id in unique_doc_ids:
    # doc_spans[doc_id] = span_dict_for_doc(doc_id) #for spans
    raw_training_text_per_doc[doc_id] = span_dict_for_doc(doc_id) #for text_sec

tokenized_training_docs = {}
for doc_id in raw_training_text_per_doc:
    spans_dic = raw_training_text_per_doc[doc_id]
    preprocessed_spans = {}
    for key, value in spans_dic.items():
        #simplest preprocessing from gemsim
        preprocessed_spans[key] = simple_preprocess(value, deacc=True)
    tokenized_training_docs[doc_id] = preprocessed_spans

tokenized_training_docs
# Out:
# {'Benefits Planner: Retirement | Benefits For Your Spouse | Social Security Administration#1_0': {'1': ['benefits',
#    'planner',
#    'retirement'],
#   '2': ['benefits', 'for', 'your', 'spouse'],
#   '3': ['even',
#    'if',
#    'you',
#    'have',
#    'never',
#    'worked',
#    'under',
#    'social',
#    'security'],
#   '4': ['you',
#    'may',
#    'be',
#    'able',
#    'to',
#    'get',
#    'spouse',
#    'retirement',
#    'benefits',
#    'if',
#    'you',
#    'are',
#    'at',
#    'least',
#    'years',
#    'of',
#    'age',
#    'and',
#    'your',
#    'spouse',
#    'is',
#    'receiving',
#    'retirement',
#    'or',
#    'disability',
#    'benefits'],
#   '5': ['you', 'can', 'also', 'qualify', 'for', 'medicare', 'at', 'age'],
#   '6': ['if', 'you', 'are', 'divorced'],
#   '7': ['you',
#    'may',
#    'still',
#    'be',
#    'able',
#    'to',
#    'get',
#    'benefits',
#    'on',
#    'your',
#    'ex',
#    'spouse',
#    'record'],
#   '8': ['for',
#    'information',
#    'on',
#    'the',
#    'requirements',
#    'for',
#    'divorced',
#    'spouse',
#    'benefits'],
#   '9': ['read', 'if', 'you', 'are', 'divorced'],
#   '10': ['you',
#    'can',
#    'receive',
#    'the',
#    'spouse',
#    'benefit',
#    'no',
#    'matter',
#    'what',
#    'your',
#    'age',
#    'is',
#    'if',
#    'you',
#    'are',
#    'caring',
#    'for',
#    'their',
#    'child',
#    'who',
#    'is',
#    'also',
#    'receiving',
#    'benefits'],
#   '11': ['how', 'much', 'will', 'receive'],
#   '12': ['if',
#    'you',
#    'qualify',
#    'and',
#    'apply',
#    'for',
#    'your',
#    'own',
#    'retirement',
#    'benefits',
#    'and',
#    'for',
#    'benefits',
#    'as',
#    'spouse'],
#   '13': ['we', 'always', 'pay', 'your', 'own', 'benefits', 'first'],
#   '14': ['if',
#    'your',
#    'benefits',
#    'as',
#    'spouse',
#    'are',
#    'higher',
#    'than',
#    'your',
#    'own',
#    'retirement',
#    'benefits'],
#   '15': ['you',
#    'will',
#    'get',
#    'combination',
#    'of',
#    'benefits',
#    'equaling',
#    'the',
#    'higher',
#    'spouse',
#    'benefit'],
#   '16': ['if', 'you', 'begin', 'receiving', 'benefits'],
#   '17': ['between', 'age', 'and', 'your', 'full', 'retirement', 'age'],
#   '18': ['the',
#    'amount',
#    'will',
#    'be',
#    'permanently',
#    'reduced',
#    'by',
#    'percentage',
#    'based',
#    'on',
#    'the',
#    'number',
#    'of',
#    'months',
#    'up',
#    'to',
#    'your',
#    'full',
#    'retirement',
#    'age'],
#   '19': ['if',
#    'you',
#    'are',
#    'under',
#    'full',
#    'retirement',
#    'age',
#    'and',
#    'you',
#    'continue',
#    'to',
#    'work',
#    'while',
#    'receiving',
#    'benefits'],
#   '20': ['your',
#    'benefits',
#    'may',
#    'be',
#    'affected',
#    'by',
#    'the',
#    'retirement',
#    'earnings',
#    'test'],
#   '21': ['at', 'your', 'full', 'retirement', 'age'],
#   '22': ['your',
#    'benefit',
#    'as',
#    'spouse',
#    'cannot',
#    'exceed',
#    'one',
#    'half',
#    'of',
#    'your',
#    'spouse',
#    'full',
#    'retirement',
#    'amount'],
#   '23': ['if',
#    'you',
#    'were',
#    'born',
#    'before',
#    'january',
#    'and',
#    'have',
#    'already',
#    'reached',
#    'full',
#    'retirement',
#    'age'],
#   '24': ['you',
#    'can',
#    'choose',
#    'to',
#    'receive',
#    'only',
#    'the',
#    'spouse',
#    'benefit',
#    'and',
#    'delay',
#    'receiving',
#    'your',
#    'retirement',
#    'benefit',
#    'until',
#    'later',
#    'date'],
#   '25': ['if',
#    'your',
#    'spouse',
#    'is',
#    'full',
#    'retirement',
#    'age',
#    'and',
#    'applying',
#    'for',
#    'spouse',
#    'benefits',
#    'only'],
#   '26': ['they',
#    'can',
#    'apply',
#    'online',
#    'by',
#    'using',
#    'the',
#    'retirement',
#    'application'],
#   '27': ['your',
#    'spouse',
#    'can',
#    'also',
#    'contact',
#    'us',
#    'to',
#    'schedule',
#    'an',
#    'appointment'],
#   '28': ['if', 'your', 'spouse', 'birthday', 'is', 'january', 'or', 'later'],
#   '29': ['the',
#    'option',
#    'to',
#    'take',
#    'only',
#    'one',
#    'benefit',
#    'at',
#    'full',
#    'retirement',
#    'age',
#    'no',
#    'longer',
#    'exists'],
#   '30': ['if', 'your', 'spouse', 'files', 'for', 'one', 'benefit'],
#   '31': ['they',
#    'will',
#    'be',
#    'effectively',
#    'filing',
#    'for',
#    'all',
#    'retirement',
#    'or',
#    'spousal',
#    'benefits'],
#   '32': ['if',
#    'you',
#    'will',
#    'receive',
#    'pension',
#    'for',
#    'work',
#    'not',
#    'covered',
#    'by',
#    'social',
#    'security',
#    'such',
#    'as',
#    'government',
#    'employment'],
#   '33': ['the',
#    'amount',
#    'of',
#    'your',
#    'social',
#    'security',
#    'benefits',
#    'on',
#    'your',
#    'spouse',
#    'record',
#    'may',
#    'be',
#    'reduced'],
#   '34': ['benefits',
#    'paid',
#    'to',
#    'you',
#    'as',
#    'spouse',
#    'will',
#    'not',
#    'decrease',
#    'your',
#    'spouse',
#    'retirement',
#    'benefit'],
#   '35': ['in', 'fact'],
#   '36': ['the',
#    'value',
#    'of',
#    'the',
#    'benefits',
#    'you',
#    'may',
#    'receive',
#    'added',
#    'to',
#    'their',
#    'benefits',
#    'may',
#    'help',
#    'your',
#    'spouse',
#    'decide',
#    'if',
#    'taking',
#    'benefits',
#    'sooner',
#    'may',
#    'be',
#    'more',
#    'advantageous'],
#   '37': ['maximum', 'family', 'benefits'],
#   '38': ['if',
#    'one',
#    'of',
#    'your',
#    'spouse',
#    'children',
#    'also',
#    'qualifies',
#    'for',
#    'benefits'],
#   '39': ['there',
#    'is',
#    'limit',
#    'to',
#    'the',
#    'amount',
#    'we',
#    'can',
#    'pay',
#    'family',
#    'members'],
#   '40': ['the',
#    'total',
#    'depends',
#    'on',
#    'your',
#    'spouse',
#    'benefit',
#    'amount',
#    'and',
#    'the',
#    'number',
#    'of',
#    'family',
#    'members',
#    'who',
#    'also',
#    'qualify',
#    'on',
#    'the',
#    'same',
#    'record'],
#   '41': ['the', 'total', 'varies'],
#   '42': ['but',
#    'generally',
#    'the',
#    'total',
#    'amount',
#    'the',
#    'worker',
#    'your',
#    'spouse',
#    'and',
#    'their',
#    'family',
#    'members',
#    'can',
#    'receive',
#    'is',
#    'about',
#    'to',
#    'percent',
#    'of',
#    'the',
#    'worker',
#    'full',
#    'retirement',
#    'benefit'],
#   '43': ['how', 'do', 'apply'],
#   '44': ['you', 'can', 'apply'],
#   '45': ['online',
#    'use',
#    'our',
#    'social',
#    'security',
#    'retirement',
#    'medicare',
#    'benefit',
#    'application',
#    'to',
#    'apply',
#    'for',
#    'retirement',
#    'spouse',
#    'divorced',
#    'spouse',
#    'or',
#    'medicare',
#    'benefits'],
#   '46': ['if',
#    'your',
#    'spouse',
#    'is',
#    'already',
#    'receiving',
#    'benefits',
#    'when',
#    'you',
#    'apply'],
#   '47': ['or',
#    'if',
#    'you',
#    'and',
#    'your',
#    'spouse',
#    'apply',
#    'at',
#    'the',
#    'same',
#    'time'],
#   '48': ['we',
#    'will',
#    'also',
#    'check',
#    'your',
#    'eligibility',
#    'for',
#    'benefits',
#    'as',
#    'spouse'],
#   '49': ['if', 'you', 'qualify'],
#   '50': ['your',
#    'application',
#    'will',
#    'automatically',
#    'serve',
#    'as',
#    'request',
#    'for',
#    'spousal',
#    'benefits'],
#   '51': ['by', 'phone', 'call', 'us', 'at'],
#   '52': ['if', 'you', 'are', 'deaf', 'or', 'hard', 'of', 'hearing'],
#   '53': ['you', 'can', 'call', 'us', 'at', 'tty'],
#   '54': ['in',
#    'person',
#    'visit',
#    'your',
#    'local',
#    'social',
#    'security',
#    'office'],
#   '55': ['call', 'first', 'to', 'make', 'an', 'appointment'],
#   '56': ['if',
#    'you',
#    'do',
#    'not',
#    'live',
#    'in',
#    'the',
#    'or',
#    'one',
#    'of',
#    'its',
#    'territories'],
#   '57': ['you',
#    'can',
#    'also',
#    'contact',
#    'the',
#    'nearest',
#    'social',
#    'security',
#    'office',
#    'embassy',
#    'or',
#    'consulate'],
#   '58': ['next', 'steps'],
#   '59': ['even',
#    'if',
#    'you',
#    'do',
#    'not',
#    'qualify',
#    'for',
#    'benefits',
#    'on',
#    'someone',
#    'else',
#    'record'],
#   '60': ['some',
#    'members',
#    'of',
#    'your',
#    'family',
#    'may',
#    'qualify',
#    'for',
#    'benefits',
#    'on',
#    'your',
#    'record'],
#   '61': ['if', 'you'],
#   '62': ['are',
#    'interested',
#    'in',
#    'information',
#    'about',
#    'benefits',
#    'for',
#    'your',
#    'family',
#    'go',
#    'to',
#    'benefits',
#    'for',
#    'your',
#    'family'],
#   '63': [],
#   '64': ['never', 'married', 'or', 'had', 'children'],
#   '65': ['go',
#    'to',
#    'how',
#    'you',
#    'apply',
#    'for',
#    'retirement',
#    'benefits',
#    'or',
#    'medicare'],
#   '66': []},
#  'Totally Disabled Or Terminally Ill Policyholders | Veterans Affairs#1_0': {'1': ['totally',
#    'disabled',
#    'or',
#    'terminally',
#    'ill',
#    'policyholders'],
#   '2': ['if',
#    'you',
#    'have',
#    'va',
#    'life',
#    'insurance',
#    'coverage',
#    'and',
#    'you',
#    'become',
#    'totally',
#    'disabled',
#    'or',
#    'terminally',
#    'ill'],
#   '3': ['you',
#    'may',
#    'be',
#    'eligible',
#    'for',
#    'certain',
#    'benefit',
#    'options'],
#   '4': ['your',
#    'spouse',
#    'may',
#    'also',
#    'be',
#    'eligible',
#    'for',
#    'certain',
#    'options',
#    'if',
#    'diagnosed',
#    'with',
#    'terminal',
#    'illness'],
#   '5': ['learn',
#    'more',
#    'about',
#    'these',
#    'options',
#    'and',
#    'how',
#    'to',
#    'apply'],
#   '6': ['on', 'this', 'page'],
#   '7': ['sgli',
#    'extension',
#    'for',
#    'policyholders',
#    'who',
#    'become',
#    'disabled'],
#   '8': ['waiver',
#    'of',
#    'premiums',
#    'for',
#    'policyholders',
#    'who',
#    'become',
#    'totally',
#    'disabled'],
#   '9': ['accelerated',
#    'benefits',
#    'for',
#    'terminally',
#    'ill',
#    'policyholders'],
#   '10': ['sgli',
#    'extension',
#    'for',
#    'policyholders',
#    'who',
#    'become',
#    'disabled'],
#   '11': ['can',
#    'get',
#    'free',
#    'extension',
#    'of',
#    'my',
#    'sgli',
#    'coverage',
#    'if',
#    'disabled',
#    'when',
#    'leave',
#    'the',
#    'military'],
#   '12': ['you',
#    'may',
#    'be',
#    'able',
#    'to',
#    'keep',
#    'your',
#    'coverage',
#    'for',
#    'up',
#    'to',
#    'years',
#    'after',
#    'the',
#    'date',
#    'you',
#    'left',
#    'the',
#    'military',
#    'if',
#    'you',
#    'meet',
#    'both',
#    'of',
#    'the',
#    'requirements',
#    'listed',
#    'below'],
#   '13': ['both', 'of', 'these', 'must', 'be', 'true'],
#   '14': ['you', 're'],
#   '15': ['within', 'years', 'of', 'your', 'separation', 'date'],
#   '16': ['and'],
#   '17': ['totally', 'disabled', 'or', 'have', 'certain', 'conditions'],
#   '18': ['find',
#    'out',
#    'if',
#    'you',
#    'qualify',
#    'for',
#    'the',
#    'sgli',
#    'disability',
#    'extension',
#    'and',
#    'how',
#    'to',
#    'apply'],
#   '19': ['waiver',
#    'of',
#    'premiums',
#    'for',
#    'policyholders',
#    'who',
#    'become',
#    'totally',
#    'disabled'],
#   '20': ['waiver',
#    'of',
#    'premiums',
#    'means',
#    'you',
#    'won',
#    'have',
#    'to',
#    'pay',
#    'your',
#    'life',
#    'insurance',
#    'premiums',
#    'the',
#    'monthly',
#    'payments',
#    'you',
#    'make',
#    'to',
#    'hold',
#    'your',
#    'policy'],
#   '21': ['in', 'most', 'cases'],
#   '22': ['premiums',
#    'can',
#    'only',
#    'be',
#    'waived',
#    'up',
#    'to',
#    'one',
#    'year',
#    'prior',
#    'to',
#    'receipt',
#    'of',
#    'claim'],
#   '23': ['you',
#    'may',
#    'be',
#    'able',
#    'to',
#    'get',
#    'waiver',
#    'of',
#    'your',
#    'life',
#    'insurance',
#    'premiums',
#    'if',
#    'you',
#    'meet',
#    'all',
#    'of',
#    'the',
#    'requirements',
#    'listed',
#    'below'],
#   '24': ['all', 'of', 'these', 'must', 'be', 'true'],
#   '25': ['you',
#    'have',
#    'mental',
#    'or',
#    'physical',
#    'disability',
#    'that',
#    'prevents',
#    'you',
#    'from',
#    'being',
#    'able',
#    'to',
#    'hold',
#    'job'],
#   '26': ['and'],
#   '27': ['you',
#    're',
#    'covered',
#    'under',
#    'service',
#    'disabled',
#    'veterans',
#    'life',
#    'insurance',
#    'dvi'],
#   '28': ['and'],
#   '29': ['your',
#    'total',
#    'disability',
#    'happens',
#    'before',
#    'you',
#    're',
#    'years',
#    'old',
#    'but',
#    'after',
#    'the',
#    'effective',
#    'date',
#    'of',
#    'your',
#    'life',
#    'insurance',
#    'policy'],
#   '30': ['and'],
#   '31': ['your',
#    'total',
#    'disability',
#    'continues',
#    'for',
#    'at',
#    'least',
#    'months',
#    'in',
#    'row'],
#   '32': ['there',
#    'are',
#    'certain',
#    'exceptions',
#    'to',
#    'the',
#    'above',
#    'conditions'],
#   '33': ['but',
#    'if',
#    'you',
#    'think',
#    'you',
#    're',
#    'entitled',
#    'to',
#    'waiver',
#    'of',
#    'premiums'],
#   '34': ['you',
#    'should',
#    'apply',
#    'as',
#    'soon',
#    'as',
#    'possible',
#    'and',
#    'we',
#    'll',
#    'let',
#    'you',
#    'know',
#    'if',
#    'you',
#    'qualify'],
#   '35': ['you',
#    'll',
#    'need',
#    'to',
#    'apply',
#    'for',
#    'these',
#    'benefits',
#    'as',
#    'soon',
#    'as',
#    'possible',
#    'after',
#    'becoming',
#    'totally',
#    'disabled'],
#   '36': ['we', 'll', 'decide', 'if', 'you', 'qualify'],
#   '37': ['and', 'we', 'll', 'notify', 'you', 'of', 'the', 'decision'],
#   '38': ['to', 'apply'],
#   '39': ['fill',
#    'out',
#    'and',
#    'sign',
#    'claim',
#    'for',
#    'disability',
#    'insurance',
#    'va',
#    'form'],
#   '40': ['mail', 'it', 'to', 'the', 'address', 'listed', 'on', 'the', 'form'],
#   '41': ['download', 'va', 'form', 'pdf'],
#   '42': ['accelerated',
#    'benefits',
#    'for',
#    'terminally',
#    'ill',
#    'policyholders'],
#   '43': ['eligible',
#    'veterans',
#    'service',
#    'members',
#    'and',
#    'covered',
#    'spouses',
#    'of',
#    'service',
#    'members',
#    'can',
#    'get',
#    'accelerated',
#    'benefits'],
#   '44': ['with', 'accelerated', 'benefits'],
#   '45': ['you',
#    'can',
#    'get',
#    'up',
#    'to',
#    'of',
#    'the',
#    'face',
#    'value',
#    'of',
#    'your',
#    'coverage',
#    'in',
#    'increments',
#    'of',
#    'paid',
#    'to',
#    'you',
#    'before',
#    'death'],
#   '46': ['you',
#    'or',
#    'your',
#    'spouse',
#    'may',
#    'be',
#    'able',
#    'to',
#    'get',
#    'benefits',
#    'early',
#    'if',
#    'you',
#    'meet',
#    'both',
#    'of',
#    'the',
#    'requirements',
#    'listed',
#    'below'],
#   '47': ['both', 'of', 'these', 'must', 'be', 'true'],
#   '48': ['you',
#    'have',
#    'sgli',
#    'family',
#    'sgli',
#    'or',
#    'vgli',
#    'life',
#    'insurance',
#    'and'],
#   '49': ['you',
#    'or',
#    'your',
#    'covered',
#    'spouse',
#    'has',
#    'written',
#    'statement',
#    'from',
#    'doctor',
#    'saying',
#    'you',
#    'have',
#    'or',
#    'your',
#    'spouse',
#    'has',
#    'months',
#    'or',
#    'less',
#    'to',
#    'live'],
#   '50': ['note'],
#   '51': ['only',
#    'the',
#    'insured',
#    'service',
#    'member',
#    'or',
#    'veteran',
#    'may',
#    'apply',
#    'for',
#    'accelerated',
#    'benefits'],
#   '52': ['no', 'one', 'may', 'apply', 'on', 'their', 'behalf'],
#   '53': ['in', 'the', 'case', 'of', 'terminally', 'ill', 'spouse'],
#   '54': ['only', 'the', 'insured', 'may', 'apply'],
#   '55': ['only',
#    'the',
#    'insured',
#    'service',
#    'member',
#    'or',
#    'veteran',
#    'may',
#    'apply',
#    'for',
#    'accelerated',
#    'benefits'],
#   '56': ['no', 'one', 'may', 'apply', 'on', 'their', 'behalf'],
#   '57': ['in', 'the', 'case', 'of', 'terminally', 'ill', 'spouse'],
#   '58': ['only', 'the', 'insured', 'may', 'apply'],
#   '59': ['use',
#    'the',
#    'application',
#    'form',
#    'for',
#    'the',
#    'type',
#    'of',
#    'coverage',
#    'you',
#    'have'],
#   '60': ['if', 'you', 're', 'an', 'sgli', 'or', 'vgli', 'policyholder'],
#   '61': ['fill', 'out', 'claim', 'for', 'accelerated', 'benefits', 'sglv'],
#   '62': ['download', 'the', 'claim', 'for', 'accelerated', 'benefits', 'form'],
#   '63': ['if',
#    'you',
#    're',
#    'still',
#    'on',
#    'active',
#    'duty',
#    'or',
#    'you',
#    're',
#    'reservist'],
#   '64': ['turn', 'in', 'the', 'form', 'to', 'your', 'service', 'branch'],
#   '65': ['they',
#    'will',
#    'need',
#    'to',
#    'fill',
#    'out',
#    'part',
#    'of',
#    'the',
#    'form'],
#   '66': ['if', 'you', 're', 'veteran'],
#   '67': ['have',
#    'your',
#    'doctor',
#    'fill',
#    'out',
#    'their',
#    'part',
#    'of',
#    'the',
#    'form',
#    'then',
#    'send',
#    'the',
#    'completed',
#    'form',
#    'to'],
#   '68': ['the',
#    'prudential',
#    'insurance',
#    'company',
#    'of',
#    'america',
#    'po',
#    'box',
#    'philadelphia'],
#   '69': ['pa'],
#   '70': ['or'],
#   '71': ['fax', 'the', 'form', 'to'],
#   '72': ['if', 'you', 're', 'covered', 'under', 'family', 'sgli'],
#   '73': ['fill', 'out', 'claim', 'for', 'accelerated', 'benefits', 'sglv'],
#   '74': ['download', 'the', 'claim', 'for', 'accelerated', 'benefits', 'form'],
#   '75': ['you',
#    'll',
#    'need',
#    'to',
#    'fill',
#    'out',
#    'one',
#    'part',
#    'of',
#    'the',
#    'application'],
#   '76': ['and',
#    'your',
#    'doctor',
#    'will',
#    'need',
#    'to',
#    'fill',
#    'out',
#    'another',
#    'part',
#    'of',
#    'it'],
#   '77': ['we',
#    'pay',
#    'the',
#    'remaining',
#    'amount',
#    'of',
#    'the',
#    'face',
#    'value',
#    'of',
#    'the',
#    'insurance',
#    'policy',
#    'to',
#    'your',
#    'designated',
#    'beneficiary',
#    'or',
#    'beneficiaries',
#    'the',
#    'people',
#    'you',
#    've',
#    'picked',
#    'to',
#    'get',
#    'the',
#    'money',
#    'from',
#    'your',
#    'policy',
#    'upon',
#    'your',
#    'death'],
#   '78': ['in', 'the', 'case', 'of', 'terminally', 'ill', 'spouse'],
#   '79': ['we',
#    'pay',
#    'the',
#    'rest',
#    'of',
#    'the',
#    'insurance',
#    'policy',
#    'to',
#    'you',
#    'upon',
#    'your',
#    'spouse',
#    'death'],
#   '80': ['learn', 'more', 'about', 'va', 'life', 'insurance'],
#   '81': ['read',
#    'chapter',
#    'of',
#    'the',
#    'servicemembers',
#    'and',
#    'veterans',
#    'group',
#    'life',
#    'insurance',
#    'handbookcontact',
#    'the',
#    'office',
#    'of',
#    'servicemembers',
#    'group',
#    'life',
#    'insurance',
#    'osgli']},
#  'Information and Instructions About Your Certificate of Title#3_0': {'1': ['what',
#    'is',
#    'title'],
#   '2': ['certificate',
#    'of',
#    'title',
#    'mv',
#    'is',
#    'the',
#    'official',
#    'proof',
#    'of',
#    'ownership',
#    'for',
#    'car',
#    'truck',
#    'motorcycle',
#    'motorboat',
#    'travel',
#    'or',
#    'utility',
#    'trailer',
#    'weighing',
#    'pounds',
#    'or',
#    'more',
#    'or',
#    'manufactured',
#    'home',
#    'mobile',
#    'home'],
#   '3': ['the',
#    'title',
#    'certificate',
#    'is',
#    'used',
#    'to',
#    'transfer',
#    'ownership',
#    'from',
#    'one',
#    'person',
#    'to',
#    'another'],
#   '4': ['the',
#    'title',
#    'also',
#    'lists',
#    'any',
#    'lienholders',
#    'those',
#    'from',
#    'whom',
#    'the',
#    'owner',
#    'borrowed',
#    'money',
#    'to',
#    'purchase',
#    'the',
#    'vehicle',
#    'or',
#    'manufactured',
#    'home'],
#   '5': ['it',
#    'is',
#    'wise',
#    'to',
#    'keep',
#    'your',
#    'title',
#    'certificate',
#    'in',
#    'safe',
#    'place'],
#   '6': ['don',
#    'keep',
#    'it',
#    'in',
#    'the',
#    'car',
#    'or',
#    'carry',
#    'it',
#    'with',
#    'you'],
#   '7': ['which', 'vehicles', 'must', 'be', 'titled'],
#   '8': ['new',
#    'york',
#    'state',
#    'issues',
#    'certificate',
#    'of',
#    'title',
#    'mv',
#    'for'],
#   '9': ['most', 'motor', 'vehicles', 'of', 'model', 'year', 'or', 'newer'],
#   '10': ['motorboats',
#    'model',
#    'year',
#    'or',
#    'newer',
#    'that',
#    'are',
#    'feet',
#    'or',
#    'longer'],
#   '11': ['and'],
#   '12': ['manufactured', 'homes'],
#   '13': ['model', 'year'],
#   '14': ['or', 'newer'],
#   '15': ['that',
#    'are',
#    'feet',
#    'or',
#    'more',
#    'in',
#    'width',
#    'or',
#    'feet',
#    'or',
#    'more',
#    'in',
#    'length',
#    'or',
#    'cover',
#    'at',
#    'least',
#    'square',
#    'feet',
#    'when',
#    'erected',
#    'on',
#    'site'],
#   '16': ['new',
#    'york',
#    'state',
#    'does',
#    'not',
#    'issue',
#    'title',
#    'certificate',
#    'for',
#    'any',
#    'motor',
#    'vehicle',
#    'of',
#    'model',
#    'year',
#    'or',
#    'older',
#    'travel',
#    'or',
#    'utility',
#    'trailer',
#    'that',
#    'weighs',
#    'less',
#    'than',
#    'pounds',
#    'or',
#    'limited',
#    'used',
#    'motorcycle',
#    'including',
#    'moped'],
#   '17': ['what',
#    'the',
#    'difference',
#    'between',
#    'title',
#    'and',
#    'registration'],
#   '18': ['for', 'most', 'owners'],
#   '19': ['title',
#    'certificate',
#    'proves',
#    'ownership',
#    'of',
#    'car',
#    'truck',
#    'motorcycle',
#    'motorboat',
#    'or',
#    'manufactured',
#    'home'],
#   '20': ['the',
#    'title',
#    'is',
#    'used',
#    'to',
#    'transfer',
#    'it',
#    'to',
#    'another',
#    'owner'],
#   '21': ['registration',
#    'allows',
#    'driver',
#    'to',
#    'operate',
#    'motor',
#    'vehicle',
#    'on',
#    'public',
#    'road',
#    'or',
#    'motorboat',
#    'on',
#    'public',
#    'waterway'],
#   '22': ['manufactured', 'homes', 'are', 'not', 'registered'],
#   '23': ['transferable',
#    'registration',
#    'is',
#    'issued',
#    'for',
#    'or',
#    'older',
#    'motor',
#    'vehicle',
#    'or',
#    'or',
#    'older',
#    'motorboat'],
#   '24': ['the',
#    'transferable',
#    'portion',
#    'proves',
#    'ownership',
#    'and',
#    'is',
#    'used',
#    'to',
#    'sell',
#    'or',
#    'give',
#    'ownership',
#    'to',
#    'another',
#    'person'],
#   '25': ['the',
#    'registration',
#    'portion',
#    'allows',
#    'the',
#    'vehicle',
#    'to',
#    'be',
#    'operated',
#    'on',
#    'public',
#    'road',
#    'or',
#    'motorboat',
#    'on',
#    'public',
#    'waterway'],
#   '26': ['how', 'do', 'obtain', 'title'],
#   '27': ['most', 'often'],
#   '28': ['you',
#    'automatically',
#    'apply',
#    'for',
#    'when',
#    'you',
#    'first',
#    'register',
#    'your',
#    'motor',
#    'vehicle',
#    'or',
#    'motorboat'],
#   '29': ['use',
#    'the',
#    'form',
#    'vehicle',
#    'registration',
#    'title',
#    'application',
#    'pdf',
#    'mv',
#    'available',
#    'at',
#    'any',
#    'motor',
#    'vehicle',
#    'office',
#    'by',
#    'request',
#    'from',
#    'dmv',
#    'call',
#    'center',
#    'or',
#    'by',
#    'download',
#    'from',
#    'the',
#    'dmv',
#    'internet',
#    'site'],
#   '30': ['you',
#    'must',
#    'pay',
#    'the',
#    'registration',
#    'and',
#    'license',
#    'plate',
#    'fees',
#    'any',
#    'appropriate',
#    'sales',
#    'tax',
#    'and',
#    'the',
#    'fee',
#    'for',
#    'title',
#    'certificate'],
#   '31': ['the',
#    'same',
#    'process',
#    'is',
#    'followed',
#    'by',
#    'dealership',
#    'that',
#    'handles',
#    'your',
#    'registration',
#    'and',
#    'title',
#    'application'],
#   '32': ['the',
#    'dealership',
#    'will',
#    'issue',
#    'you',
#    'temporary',
#    'registration'],
#   '33': ['you',
#    'will',
#    'receive',
#    'your',
#    'permanent',
#    'registration',
#    'and',
#    'license',
#    'plates',
#    'if',
#    'requested',
#    'when',
#    'the',
#    'department',
#    'of',
#    'motor',
#    'vehicles',
#    'accepts',
#    'your',
#    'application'],
#   '34': ['however'],
#   '35': ['new',
#    'york',
#    'state',
#    'title',
#    'certificates',
#    'are',
#    'not',
#    'issued',
#    'over',
#    'the',
#    'counter'],
#   '36': ['state',
#    'law',
#    'requires',
#    'the',
#    'dmv',
#    'to',
#    'mail',
#    'title',
#    'certificate',
#    'to',
#    'the',
#    'owner',
#    'after',
#    'carefully',
#    'examining',
#    'and',
#    'verifying',
#    'the',
#    'proof',
#    'of',
#    'ownership',
#    'submitted',
#    'with',
#    'the',
#    'application'],
#   '37': ['as', 'result'],
#   '38': ['the',
#    'title',
#    'application',
#    'process',
#    'may',
#    'take',
#    'several',
#    'weeks',
#    'to',
#    'complete'],
#   '39': ['if',
#    'you',
#    'do',
#    'not',
#    'receive',
#    'your',
#    'title',
#    'certificate',
#    'by',
#    'mail',
#    'within',
#    'days',
#    'after',
#    'you',
#    'apply'],
#   '40': ['contact', 'dmv', 'call', 'center'],
#   '41': ['your',
#    'registration',
#    'receipt',
#    'can',
#    'help',
#    'verify',
#    'your',
#    'vehicle',
#    'plate',
#    'number',
#    'make',
#    'year',
#    'and',
#    'vehicle',
#    'identification',
#    'number',
#    'vin'],
#   '42': ['when', 'you', 'receive', 'your', 'title'],
#   '43': ['check',
#    'to',
#    'see',
#    'whether',
#    'the',
#    'information',
#    'it',
#    'contains',
#    'about',
#    'your',
#    'vehicle',
#    'is',
#    'correct',
#    'and',
#    'agrees',
#    'with',
#    'the',
#    'information',
#    'on',
#    'the',
#    'vehicle',
#    'registration',
#    'document'],
#   '44': ['if', 'the', 'title', 'is', 'incorrect'],
#   '45': ['contact',
#    'the',
#    'dmv',
#    'call',
#    'center',
#    'and',
#    'ask',
#    'about',
#    'obtaining',
#    'an',
#    'amended',
#    'title'],
#   '46': ['if',
#    'both',
#    'the',
#    'registration',
#    'and',
#    'title',
#    'are',
#    'incorrect'],
#   '47': ['bring', 'them', 'to', 'motor', 'vehicle', 'office'],
#   '48': ['how', 'do', 'obtain', 'title', 'if', 'don', 'want', 'registration'],
#   '49': ['this', 'is', 'known', 'as', 'title', 'only', 'transaction'],
#   '50': ['fill',
#    'out',
#    'vehicle',
#    'registration',
#    'title',
#    'application',
#    'pdf',
#    'mv',
#    'or',
#    'application',
#    'for',
#    'title',
#    'pdf',
#    'mv',
#    'ton',
#    'available',
#    'at',
#    'any',
#    'motor',
#    'vehicle',
#    'office'],
#   '51': ['it',
#    'is',
#    'also',
#    'available',
#    'by',
#    'request',
#    'from',
#    'dmv',
#    'call',
#    'center',
#    'or',
#    'from',
#    'the',
#    'dmv',
#    'internet',
#    'office'],
#   '52': ['when', 'applying', 'only', 'for', 'title', 'certificate'],
#   '53': ['you',
#    'must',
#    'pay',
#    'the',
#    'sales',
#    'tax',
#    'at',
#    'motor',
#    'vehicle',
#    'office'],
#   '54': ['bring',
#    'your',
#    'proof',
#    'of',
#    'ownership',
#    'and',
#    'proof',
#    'of',
#    'purchase',
#    'price'],
#   '55': ['the',
#    'most',
#    'commonly',
#    'accepted',
#    'proof',
#    'of',
#    'purchase',
#    'price',
#    'is',
#    'an',
#    'statement',
#    'of',
#    'transaction',
#    'sale',
#    'or',
#    'gift',
#    'of',
#    'motor',
#    'vehicle',
#    'trailer',
#    'all',
#    'terrain',
#    'vehicle',
#    'atv',
#    'vessel',
#    'boat',
#    'or',
#    'snowmobile',
#    'pdf',
#    'at',
#    'ny',
#    'state',
#    'department',
#    'of',
#    'tax',
#    'and',
#    'finance',
#    'dtf',
#    'available',
#    'at',
#    'any',
#    'motor',
#    'vehicle',
#    'office',
#    'or',
#    'by',
#    'from',
#    'the',
#    'dmv',
#    'internet',
#    'office'],
#   '56': ['both',
#    'the',
#    'seller',
#    'and',
#    'the',
#    'buyer',
#    'must',
#    'complete',
#    'the',
#    'affidavit',
#    'of',
#    'sale',
#    'statement'],
#   '57': ['attach',
#    'your',
#    'receipt',
#    'for',
#    'sales',
#    'tax',
#    'payment',
#    'fs',
#    'to',
#    'your',
#    'vehicle',
#    'registration',
#    'title',
#    'application'],
#   '58': ['do',
#    'not',
#    'send',
#    'sales',
#    'tax',
#    'payments',
#    'to',
#    'the',
#    'title',
#    'bureau'],
#   '59': ['to',
#    'apply',
#    'for',
#    'title',
#    'only',
#    'because',
#    'of',
#    'or',
#    'for',
#    'vehicle',
#    'you',
#    'will',
#    'register',
#    'under',
#    'the',
#    'dmv'],
#   '60': ['you',
#    'may',
#    'submit',
#    'vehicle',
#    'registration',
#    'title',
#    'application',
#    'to',
#    'any',
#    'motor',
#    'vehicle',
#    'office'],
#   '61': ['for', 'all', 'other', 'title', 'only', 'transactions'],
#   '62': ['you',
#    'must',
#    'mail',
#    'the',
#    'following',
#    'documents',
#    'to',
#    'the',
#    'dmv',
#    'title',
#    'bureau',
#    'nys',
#    'department',
#    'of',
#    'motor',
#    'vehicles',
#    'title',
#    'only',
#    'empire',
#    'state',
#    'plaza',
#    'albany',
#    'ny'],
#   '63': ['the', 'vehicle', 'registration', 'title', 'application'],
#   '64': ['proof',
#    'of',
#    'ownership',
#    'including',
#    'any',
#    'applicable',
#    'lien',
#    'release'],
#   '65': ['proof',
#    'of',
#    'sales',
#    'tax',
#    'payment',
#    'retail',
#    'certificate',
#    'of',
#    'sale',
#    'mv',
#    'or',
#    'receipt',
#    'for',
#    'sales',
#    'tax',
#    'payment',
#    'fs'],
#   '66': ['salvage',
#    'branding',
#    'disclosure',
#    'for',
#    'vehicles',
#    'model',
#    'years',
#    'or',
#    'newer'],
#   '67': ['the',
#    'title',
#    'certificate',
#    'fee',
#    'of',
#    'the',
#    'title',
#    'fee',
#    'for',
#    'manufactured',
#    'home',
#    'is',
#    'by',
#    'check',
#    'or',
#    'money',
#    'order',
#    'payable',
#    'to',
#    'the',
#    'commissioner',
#    'of',
#    'motor',
#    'vehicles'],
#   '68': ['what',
#    'vehicles',
#    'must',
#    'be',
#    'titled',
#    'prior',
#    'to',
#    'registration'],
#   '69': ['every',
#    'vehicle',
#    'purchased',
#    'with',
#    'garageman',
#    'lien',
#    'as',
#    'proof',
#    'of',
#    'ownership',
#    'or',
#    'any',
#    'vehicle',
#    'subject',
#    'to',
#    'the',
#    'dmv',
#    'salvage',
#    'vehicle',
#    'program',
#    'must',
#    'receive',
#    'first',
#    'be',
#    'titled',
#    'before',
#    'it',
#    'will',
#    'be',
#    'allowed',
#    'to',
#    'be',
#    'registered'],
#   '70': ['an',
#    'applicant',
#    'following',
#    'the',
#    'garageman',
#    'lien',
#    'procedure',
#    'must',
#    'present',
#    'ownership',
#    'documentation',
#    'that',
#    'includes',
#    'notice',
#    'of',
#    'lien',
#    'and',
#    'sale',
#    'pdf',
#    'mv',
#    'and',
#    'garageman',
#    'affirmation',
#    'and',
#    'bill',
#    'of',
#    'sale',
#    'pdf',
#    'mv'],
#   '71': ['an',
#    'applicant',
#    'in',
#    'the',
#    'salvage',
#    'vehicle',
#    'program',
#    'must',
#    'present',
#    'salvage',
#    'certificate',
#    'mv',
#    'and',
#    'ansalvage',
#    'examination',
#    'title',
#    'application',
#    'pdf',
#    'mv',
#    'sal'],
#   '72': ['for', 'additional', 'information'],
#   '73': ['if', 'needed'],
#   '74': ['contact', 'the', 'dmv', 'title', 'services', 'bureau', 'telephone'],
#   '75': ['the',
#    'telephone',
#    'service',
#    'is',
#    'available',
#    'on',
#    'weekdays',
#    'except',
#    'wednesdays',
#    'and',
#    'state',
#    'holidays',
#    'between',
#    'the',
#    'hours',
#    'of',
#    'and'],
#   '76': ['what', 'proof', 'of', 'ownership', 'will', 'dmv', 'accept'],
#   '77': ['when',
#    'you',
#    'apply',
#    'for',
#    'an',
#    'original',
#    'title',
#    'certificate'],
#   '78': ['you',
#    'must',
#    'provide',
#    'proof',
#    'ownership',
#    'signed',
#    'over',
#    'to',
#    'you',
#    'proof',
#    'of',
#    'sales',
#    'tax',
#    'payment',
#    'and',
#    'proof',
#    'of',
#    'identity'],
#   '79': ['for',
#    'purchase',
#    'made',
#    'from',
#    'new',
#    'york',
#    'state',
#    'registered',
#    'dealer'],
#   '80': ['the',
#    'proof',
#    'of',
#    'ownership',
#    'is',
#    'manufacturer',
#    'certificate',
#    'of',
#    'origin',
#    'mco',
#    'or',
#    'the',
#    'vehicle',
#    'certificate',
#    'of',
#    'title',
#    'mv',
#    'plus',
#    'the',
#    'dealer',
#    'certificate',
#    'of',
#    'sale',
#    'mv'],
#   '81': ['for', 'casual', 'sale'],
#   '82': ['that',
#    'is',
#    'if',
#    'you',
#    'made',
#    'your',
#    'purchase',
#    'from',
#    'an',
#    'individual',
#    'or',
#    'business',
#    'that',
#    'is',
#    'not',
#    'registered',
#    'dealership'],
#   '83': ['the',
#    'ownership',
#    'proof',
#    'is',
#    'transferred',
#    'certificate',
#    'of',
#    'title'],
#   '84': ['if',
#    'your',
#    'purchase',
#    'does',
#    'not',
#    'qualify',
#    'for',
#    'title',
#    'certificate'],
#   '85': ['the',
#    'ownership',
#    'proof',
#    'is',
#    'transferable',
#    'registration',
#    'signed',
#    'over',
#    'to',
#    'you'],
#   '86': ['if',
#    'the',
#    'listed',
#    'proofs',
#    'of',
#    'ownership',
#    'are',
#    'not',
#    'available'],
#   '87': ['contact',
#    'dmv',
#    'call',
#    'center',
#    'or',
#    'motor',
#    'vehicle',
#    'office',
#    'before',
#    'you',
#    'make',
#    'your',
#    'purchase'],
#   '88': ['without', 'proper', 'proof', 'of', 'ownership'],
#   '89': ['you',
#    'will',
#    'not',
#    'be',
#    'issued',
#    'new',
#    'york',
#    'state',
#    'certificate',
#    'of',
#    'title'],
#   '90': ['and',
#    'you',
#    'may',
#    'not',
#    'be',
#    'allowed',
#    'to',
#    'register',
#    'your',
#    'vehicle'],
#   '91': ['you',
#    'may',
#    'register',
#    'vehicle',
#    'but',
#    'not',
#    'receive',
#    'nys',
#    'certificate',
#    'of',
#    'title',
#    'if',
#    'your',
#    'vehicle',
#    'original',
#    'title',
#    'certificate',
#    'that',
#    'was',
#    'issued',
#    'outside',
#    'new',
#    'york',
#    'state',
#    'is',
#    'held',
#    'by',
#    'lienholder'],
#   '92': ['to', 'register'],
#   '93': ['your',
#    'application',
#    'for',
#    'registration',
#    'title',
#    'mv',
#    'must',
#    'include',
#    'certified',
#    'photocopy',
#    'of',
#    'the',
#    'out',
#    'of',
#    'state',
#    'title',
#    'certificate',
#    'in',
#    'your',
#    'name',
#    'or',
#    'written',
#    'verification',
#    'from',
#    'the',
#    'out',
#    'of',
#    'state',
#    'motor',
#    'vehicle',
#    'title',
#    'authority',
#    'that',
#    'you',
#    'are',
#    'the',
#    'vehicle',
#    'owner',
#    'and',
#    'that',
#    'the',
#    'other',
#    'state',
#    'authority',
#    'had',
#    'sent',
#    'the',
#    'original',
#    'title',
#    'to',
#    'the',
#    'lienholder'],
#   '94': ['if',
#    'you',
#    'own',
#    'the',
#    'vehicle',
#    'but',
#    'do',
#    'not',
#    'have',
#    'the',
#    'certified',
#    'photocopy',
#    'or',
#    'the',
#    'written',
#    'verification'],
#   '95': ['it',
#    'may',
#    'be',
#    'registered',
#    'if',
#    'you',
#    'present',
#    'an',
#    'out',
#    'of',
#    'state',
#    'registration',
#    'document',
#    'issued',
#    'in',
#    'your',
#    'name'],
#   '96': ['after', 'the', 'lien', 'is', 'satisfied'],
#   '97': ['you',
#    'will',
#    'receive',
#    'the',
#    'original',
#    'out',
#    'of',
#    'state',
#    'title',
#    'certificate',
#    'from',
#    'the',
#    'lienholder'],
#   '98': ['to',
#    'apply',
#    'for',
#    'original',
#    'nys',
#    'certificate',
#    'of',
#    'title'],
#   '99': ['you',
#    'must',
#    'mail',
#    'to',
#    'the',
#    'dmv',
#    'title',
#    'bureau',
#    'the',
#    'notice',
#    'of',
#    'lien',
#    'satisfaction',
#    'the',
#    'original',
#    'out',
#    'of',
#    'state',
#    'issued',
#    'title',
#    'certificate',
#    'and',
#    'letter',
#    'explaining',
#    'your',
#    'circumstances'],
#   '100': ['what',
#    'if',
#    'need',
#    'duplicate',
#    'title',
#    'or',
#    'if',
#    'my',
#    'title',
#    'is',
#    'lost',
#    'or',
#    'stolen'],
#   '101': ['duplicate',
#    'title',
#    'is',
#    'needed',
#    'if',
#    'your',
#    'title',
#    'certificate',
#    'has',
#    'been',
#    'damaged',
#    'lost',
#    'or',
#    'stolen'],
#   '102': ['you',
#    'may',
#    'apply',
#    'online',
#    'or',
#    'at',
#    'any',
#    'motor',
#    'vehicle',
#    'office',
#    'for',
#    'duplicate',
#    'title',
#    'with',
#    'no',
#    'change',
#    'of',
#    'address'],
#   '103': ['if', 'you', 'apply', 'at', 'an', 'office'],
#   '104': ['submit',
#    'an',
#    'application',
#    'for',
#    'duplicate',
#    'certificate',
#    'of',
#    'title',
#    'pdf',
#    'mv',
#    'and',
#    'provide',
#    'proof',
#    'of',
#    'your',
#    'identity',
#    'and',
#    'current',
#    'address'],
#   '105': ['the', 'fee', 'is'],
#   '106': ['your',
#    'duplicate',
#    'title',
#    'will',
#    'be',
#    'processed',
#    'within',
#    'hours',
#    'after',
#    'your',
#    'application',
#    'is',
#    'accepted',
#    'and',
#    'will',
#    'be',
#    'promptly',
#    'mailed',
#    'to',
#    'you'],
#   '107': ['you',
#    'also',
#    'may',
#    'mail',
#    'your',
#    'application',
#    'to',
#    'the',
#    'dmv',
#    'title',
#    'bureau',
#    'with',
#    'photocopies',
#    'of',
#    'your',
#    'proofs',
#    'of',
#    'identity',
#    'and',
#    'address',
#    'and',
#    'the',
#    'fee',
#    'by',
#    'check',
#    'or',
#    'money',
#    'order',
#    'payable',
#    'to',
#    'the',
#    'commissioner',
#    'of',
#    'motor',
#    'vehicles'],
#   '108': ['if', 'you', 'mail', 'the', 'application'],
#   '109': ['please',
#    'allow',
#    'added',
#    'time',
#    'for',
#    'postal',
#    'delivery',
#    'to',
#    'the',
#    'dmv'],
#   '110': ['please', 'note'],
#   '111': ['as',
#    'soon',
#    'as',
#    'duplicate',
#    'title',
#    'has',
#    'been',
#    'processed'],
#   '112': ['the',
#    'original',
#    'title',
#    'and',
#    'any',
#    'prior',
#    'duplicates',
#    'are',
#    'no',
#    'longer',
#    'valid',
#    'and',
#    'may',
#    'not',
#    'be',
#    'used',
#    'to',
#    'transfer',
#    'your',
#    'vehicle'],
#   '113': ['what',
#    'is',
#    'lien',
#    'and',
#    'how',
#    'is',
#    'it',
#    'recorded',
#    'on',
#    'my',
#    'title'],
#   '114': ['lien',
#    'means',
#    'that',
#    'someone',
#    'other',
#    'than',
#    'the',
#    'owner',
#    'has',
#    'security',
#    'interest',
#    'in',
#    'your',
#    'motor',
#    'vehicle',
#    'motorboat',
#    'or',
#    'manufactured',
#    'home'],
#   '115': ['this',
#    'usually',
#    'is',
#    'the',
#    'bank',
#    'or',
#    'finance',
#    'company',
#    'that',
#    'loaned',
#    'you',
#    'money',
#    'to',
#    'pay',
#    'for',
#    'its',
#    'purchase'],
#   '116': ['the',
#    'lienholder',
#    'is',
#    'listed',
#    'on',
#    'the',
#    'title',
#    'certificate',
#    'and',
#    'on',
#    'the',
#    'dmv',
#    'computer',
#    'records'],
#   '117': ['the',
#    'lienholder',
#    'or',
#    'dealership',
#    'will',
#    'complete',
#    'forms',
#    'and',
#    'pay',
#    'fee',
#    'to',
#    'have',
#    'the',
#    'dmv',
#    'record',
#    'the',
#    'lien',
#    'on',
#    'your',
#    'title'],
#   '118': ['as', 'the', 'new', 'owner'],
#   '119': ['you',
#    'probably',
#    'will',
#    'not',
#    'be',
#    'involved',
#    'in',
#    'filing',
#    'the',
#    'lien'],
#   '120': ['the',
#    'lender',
#    'cannot',
#    'charge',
#    'you',
#    'the',
#    'recording',
#    'fee'],
#   '121': ['lien',
#    'recorded',
#    'on',
#    'an',
#    'out',
#    'of',
#    'state',
#    'title',
#    'will',
#    'automatically',
#    'be',
#    'printed',
#    'on',
#    'new',
#    'york',
#    'title',
#    'certificate',
#    'unless',
#    'your',
#    'new',
#    'york',
#    'title',
#    'application',
#    'includes',
#    'proof',
#    'that',
#    'the',
#    'loan',
#    'has',
#    'been',
#    'paid',
#    'in',
#    'full'],
#   '122': ['if',
#    'lienholder',
#    'unknown',
#    'to',
#    'you',
#    'is',
#    'listed',
#    'on',
#    'your',
#    'title',
#    'certificate'],
#   '123': ['contact', 'dmv', 'call', 'center'],
#   '124': ['what',
#    'if',
#    'lienholder',
#    'has',
#    'the',
#    'original',
#    'out',
#    'of',
#    'state',
#    'title'],
#   '125': ['unless', 'the', 'lien', 'is', 'satisfied'],
#   '126': ['you',
#    'can',
#    'receive',
#    'new',
#    'york',
#    'registration',
#    'but',
#    'not',
#    'certificate',
#    'of',
#    'title'],
#   '127': ['to', 'register'],
#   '128': ['obtain',
#    'certified',
#    'photocopy',
#    'of',
#    'the',
#    'title',
#    'or',
#    'written',
#    'verification',
#    'from',
#    'the',
#    'other',
#    'state',
#    'motor',
#    'vehicle',
#    'title',
#    'authority',
#    'that',
#    'you',
#    'are',
#    'the',
#    'owner',
#    'and',
#    'letter',
#    'from',
#    'the',
#    'lienholder',
#    'authorizing',
#    'you',
#    'to',
#    'register',
#    'the',
#    'car',
#    'in',
#    'new',
#    'york'],
#   '129': ['to',
#    'receive',
#    'new',
#    'york',
#    'state',
#    'title',
#    'certificate',
#    'after',
#    'the',
#    'lien',
#    'is',
#    'satisfied'],
#   '130': ['you',
#    'must',
#    'mail',
#    'the',
#    'out',
#    'of',
#    'state',
#    'title',
#    'the',
#    'proof',
#    'of',
#    'lien',
#    'satisfaction',
#    'and',
#    'letter',
#    'of',
#    'explanation',
#    'to',
#    'the',
#    'title',
#    'bureau'],
#   '131': ['how',
#    'do',
#    'remove',
#    'lien',
#    'from',
#    'my',
#    'ny',
#    'title',
#    'and',
#    'get',
#    'clear',
#    'title'],
#   '132': ['when', 'you', 'have', 'paid', 'your', 'loan', 'in', 'full'],
#   '133': ['the',
#    'lienholder',
#    'must',
#    'promptly',
#    'send',
#    'you',
#    'proof',
#    'of',
#    'lien',
#    'satisfaction',
#    'called',
#    'lien',
#    'release'],
#   '134': [],
#   '135': ['this',
#    'is',
#    'usually',
#    'notice',
#    'of',
#    'recorded',
#    'lien',
#    'mv',
#    'marked',
#    'and',
#    'endorsed',
#    'by',
#    'the',
#    'lender',
#    'proving',
#    'payment'],
#   '136': ['it',
#    'might',
#    'also',
#    'be',
#    'letter',
#    'on',
#    'the',
#    'lender',
#    'stationery',
#    'identifying',
#    'the',
#    'borrower',
#    'name',
#    'the',
#    'vehicle',
#    'by',
#    'make',
#    'year',
#    'and',
#    'vehicle',
#    'identification',
#    'number',
#    'certifying',
#    'the',
#    'date',
#    'of',
#    'full',
#    'payment',
#    'and',
#    'release',
#    'of',
#    'the',
#    'security',
#    'interest',
#    'and',
#    'signed',
#    'by',
#    'an',
#    'officer',
#    'of',
#    'the',
#    'lending',
#    'institution'],
#   '137': ['keep', 'this', 'lien', 'release'],
#   '138': ['you',
#    'will',
#    'need',
#    'to',
#    'give',
#    'it',
#    'to',
#    'buyer',
#    'along',
#    'with',
#    'your',
#    'title',
#    'certificate',
#    'when',
#    'you',
#    'transfer',
#    'ownership'],
#   '139': ['the',
#    'dmv',
#    'will',
#    'accept',
#    'only',
#    'the',
#    'signed',
#    'original',
#    'release'],
#   '140': ['you',
#    'also',
#    'may',
#    'request',
#    'the',
#    'dmv',
#    'title',
#    'bureau',
#    'to',
#    'remove',
#    'the',
#    'lien',
#    'from',
#    'your',
#    'new',
#    'york',
#    'state',
#    'issued',
#    'title',
#    'by',
#    'mailing',
#    'the',
#    'original',
#    'lien',
#    'release',
#    'form',
#    'or',
#    'letter',
#    'the',
#    'original',
#    'title',
#    'certificate',
#    'and',
#    'check',
#    'or',
#    'money',
#    'order',
#    'for',
#    'payable',
#    'to',
#    'the',
#    'commissioner',
#    'of',
#    'motor',
#    'vehicles'],
#   '141': ['photocopies', 'are', 'not', 'accepted'],
#   '142': ['if',
#    'your',
#    'address',
#    'has',
#    'changed',
#    'since',
#    'the',
#    'title',
#    'was',
#    'issued'],
#   '143': ['send',
#    'proof',
#    'of',
#    'your',
#    'current',
#    'address',
#    'examples',
#    'photocopy',
#    'of',
#    'your',
#    'current',
#    'registration',
#    'driver',
#    'license',
#    'or',
#    'utility',
#    'bill'],
#   '144': ['new',
#    'title',
#    'certificate',
#    'that',
#    'does',
#    'not',
#    'indicate',
#    'the',
#    'lien',
#    'will',
#    'be',
#    'promptly',
#    'processed',
#    'and',
#    'mailed',
#    'to',
#    'you'],
#   '145': ['please', 'note'],
#   '146': ['you',
#    'are',
#    'not',
#    'required',
#    'to',
#    'obtain',
#    'clear',
#    'title',
#    'after',
#    'the',
#    'lien',
#    'has',
#    'been',
#    'satisfied'],
#   '147': ['keep',
#    'the',
#    'original',
#    'lien',
#    'release',
#    'attach',
#    'it',
#    'to',
#    'your',
#    'title',
#    'and',
#    'give',
#    'it',
#    'to',
#    'the',
#    'vehicle',
#    'purchaser',
#    'when',
#    'you',
#    'transfer',
#    'ownership'],
#   '148': ['how', 'do', 'transfer', 'title'],
#   '149': ['you',
#    'cannot',
#    'transfer',
#    'title',
#    'certificate',
#    'to',
#    'new',
#    'owner',
#    'if',
#    'the',
#    'reverse',
#    'side',
#    'of',
#    'the',
#    'title',
#    'is',
#    'already',
#    'signed',
#    'over',
#    'to',
#    'you'],
#   '150': ['you',
#    'first',
#    'must',
#    'obtain',
#    'title',
#    'in',
#    'your',
#    'own',
#    'name',
#    'then',
#    'transfer',
#    'it',
#    'to',
#    'the',
#    'new',
#    'owner'],
#   '151': ['the',
#    'dmv',
#    'will',
#    'not',
#    'accept',
#    'titles',
#    'with',
#    'cross',
#    'outs',
#    'alterations',
#    'or',
#    'erasures',
#    'of',
#    'any',
#    'kind'],
#   '152': ['as', 'seller'],
#   '153': ['you',
#    'must',
#    'complete',
#    'the',
#    'transfer',
#    'by',
#    'owner',
#    'section',
#    'on',
#    'the',
#    'back',
#    'of',
#    'the',
#    'title'],
#   '154': ['do', 'not', 'write', 'on', 'or', 'mark', 'the', 'front'],
#   '155': ['do',
#    'not',
#    'fill',
#    'in',
#    'any',
#    'information',
#    'until',
#    'you',
#    'actually',
#    'make',
#    'the',
#    'transfer',
#    'to',
#    'the',
#    'new',
#    'owner'],
#   '156': ['if',
#    'you',
#    'change',
#    'or',
#    'correct',
#    'any',
#    'information',
#    'including',
#    'signatures',
#    'or',
#    'addresses'],
#   '157': ['the', 'title', 'will', 'not', 'be', 'valid'],
#   '158': ['if', 'the', 'title', 'is', 'voided'],
#   '159': ['even', 'if', 'by', 'error'],
#   '160': ['you',
#    'must',
#    'obtain',
#    'duplicate',
#    'title',
#    'see',
#    'above',
#    'what',
#    'if',
#    'need',
#    'duplicate',
#    'title',
#    'or',
#    'my',
#    'title',
#    'is',
#    'lost',
#    'or',
#    'stolen'],
#   '161': ['before', 'you', 'can', 'transfer', 'ownership'],
#   '162': ['for',
#    'motor',
#    'vehicles',
#    'that',
#    'are',
#    'model',
#    'years',
#    'old',
#    'or',
#    'newer'],
#   '163': ['the',
#    'seller',
#    'must',
#    'complete',
#    'the',
#    'odometer',
#    'disclosure',
#    'statement',
#    'on',
#    'the',
#    'back',
#    'of',
#    'the',
#    'title',
#    'certificate'],
#   '164': ['for', 'vehicles', 'older', 'than', 'model', 'years'],
#   '165': ['odometer', 'disclosure', 'is', 'not', 'required'],
#   '166': ['the',
#    'damage',
#    'disclosure',
#    'statement',
#    'on',
#    'the',
#    'back',
#    'of',
#    'the',
#    'nys',
#    'title',
#    'certificate',
#    'must',
#    'be',
#    'completed',
#    'for',
#    'all',
#    'vehicles',
#    'regardless',
#    'of',
#    'the',
#    'vehicle',
#    'age'],
#   '167': ['then'],
#   '168': ['in', 'the', 'title', 'certificate', 'transfer', 'portion'],
#   '169': ['clearly',
#    'print',
#    'the',
#    'seller',
#    'name',
#    'and',
#    'address',
#    'the',
#    'buyer',
#    'name',
#    'and',
#    'address',
#    'and',
#    'the',
#    'date',
#    'of',
#    'transfer'],
#   '170': ['as', 'seller'],
#   '171': ['when',
#    'you',
#    'sign',
#    'on',
#    'the',
#    'line',
#    'for',
#    'seller',
#    'signature'],
#   '172': ['the',
#    'vehicle',
#    'will',
#    'immediately',
#    'belong',
#    'to',
#    'the',
#    'new',
#    'owner'],
#   '173': ['the',
#    'new',
#    'owner',
#    'cannot',
#    'legally',
#    'drive',
#    'the',
#    'vehicle',
#    'before',
#    'obtaining',
#    'new',
#    'license',
#    'plates',
#    'and',
#    'new',
#    'registration',
#    'or',
#    'transfer',
#    'them',
#    'from',
#    'another',
#    'registered',
#    'vehicle'],
#   '174': ['tip'],
#   '175': ['before', 'you', 'complete', 'the', 'sale'],
#   '176': ['take',
#    'your',
#    'license',
#    'plates',
#    'off',
#    'the',
#    'vehicle',
#    'and',
#    'remove',
#    'your',
#    'registration',
#    'sticker',
#    'from',
#    'the',
#    'windshield'],
#   '177': ['unless',
#    'you',
#    'transfer',
#    'the',
#    'plates',
#    'to',
#    'another',
#    'vehicle'],
#   '178': ['turn',
#    'them',
#    'in',
#    'at',
#    'dmv',
#    'office',
#    'as',
#    'soon',
#    'as',
#    'possible'],
#   '179': ['what', 'is', 'motor', 'vehicle', 'branding'],
#   '180': ['motor',
#    'vehicle',
#    'branding',
#    'is',
#    'written',
#    'notice',
#    'that',
#    'motor',
#    'vehicle',
#    'previously',
#    'either',
#    'did',
#    'not',
#    'conform',
#    'to',
#    'its',
#    'warranty',
#    'had',
#    'been',
#    'rebuilt',
#    'following',
#    'damage',
#    'in',
#    'excess',
#    'of',
#    'of',
#    'its',
#    'retail',
#    'value',
#    'at',
#    'the',
#    'time',
#    'of',
#    'loss',
#    'originally',
#    'entered',
#    'new',
#    'york',
#    'state',
#    'under',
#    'branded',
#    'out',
#    'of',
#    'state',
#    'title',
#    'had',
#    'not',
#    'been',
#    'manufactured',
#    'to',
#    'standards',
#    'has',
#    'been',
#    'reconstructed',
#    'or',
#    'is',
#    'not',
#    'equipped',
#    'with',
#    'tamper',
#    'resistant',
#    'odometer'],
#   '181': ['dealer',
#    'must',
#    'inform',
#    'customer',
#    'in',
#    'writing',
#    'if',
#    'branded',
#    'vehicle',
#    'is',
#    'being',
#    'shown',
#    'or',
#    'sold'],
#   '182': ['this',
#    'may',
#    'be',
#    'notice',
#    'placed',
#    'on',
#    'the',
#    'dealer',
#    'bill',
#    'of',
#    'sale',
#    'or',
#    'handed',
#    'to',
#    'the',
#    'customer'],
#   '183': ['the',
#    'branding',
#    'also',
#    'may',
#    'be',
#    'printed',
#    'notice',
#    'on',
#    'the',
#    'front',
#    'of',
#    'the',
#    'title'],
#   '184': ['read',
#    'the',
#    'dmv',
#    'publication',
#    'let',
#    'the',
#    'buyer',
#    'be',
#    'aware',
#    'buying',
#    'new',
#    'or',
#    'used',
#    'car',
#    'for',
#    'helpful',
#    'information',
#    'about',
#    'brands',
#    'on',
#    'titles',
#    'and',
#    'what',
#    'they',
#    'mean'],
#   '185': ['if',
#    'you',
#    'are',
#    'considering',
#    'vehicle',
#    'that',
#    'has',
#    'title',
#    'with',
#    'any',
#    'notation',
#    'you',
#    'do',
#    'not',
#    'understand'],
#   '186': ['contact',
#    'dmv',
#    'call',
#    'center',
#    'for',
#    'information',
#    'before',
#    'you',
#    'purchase',
#    'the',
#    'vehicle'],
#   '187': ['what', 'should', 'do', 'if', 'the', 'buyer'],
#   '188': ['carefully',
#    'examine',
#    'the',
#    'current',
#    'owner',
#    'certificate',
#    'of',
#    'title',
#    'mv',
#    'you',
#    'buy'],
#   '189': ['be', 'sure', 'the', 'information', 'is', 'correct'],
#   '190': ['and',
#    'that',
#    'the',
#    'title',
#    'certificate',
#    'identifies',
#    'the',
#    'motor',
#    'vehicle',
#    'motorboat',
#    'or',
#    'manufactured',
#    'home',
#    'being',
#    'sold'],
#   '191': ['compare',
#    'the',
#    'vehicle',
#    'identification',
#    'number',
#    'vin',
#    'on',
#    'the',
#    'title',
#    'with',
#    'the',
#    'actual',
#    'vin'],
#   '192': ['motorboat', 'vin', 'is', 'located', 'on', 'its', 'hull'],
#   '193': ['and',
#    'manufactured',
#    'home',
#    'vin',
#    'is',
#    'stamped',
#    'on',
#    'its',
#    'chassis'],
#   '194': ['motor',
#    'vehicle',
#    'vin',
#    'is',
#    'usually',
#    'located',
#    'on',
#    'the',
#    'driver',
#    'side',
#    'dashboard',
#    'near',
#    'the',
#    'windshield'],
#   '195': ['for', 'motor', 'vehicle', 'years', 'old', 'and', 'newer'],
#   '196': ['be',
#    'sure',
#    'the',
#    'odometer',
#    'reading',
#    'your',
#    'name',
#    'and',
#    'address',
#    'as',
#    'buyer',
#    'and',
#    'the',
#    'date',
#    'are',
#    'printed',
#    'clearly',
# ...
#   '27': ['you',
#    'must',
#    'see',
#    'your',
#    'child',
#    'ds',
#    'certificate',
#    'of',
#    'eligibility',
#    'for',
#    'exchange',
#    'visitor',
#    'status'],
#   '28': ['work', 'eligibility'],
#   '29': ['in', 'general'],
#   '30': ['only',
#    'noncitizens',
#    'who',
#    'have',
#    'permission',
#    'to',
#    'work',
#    'from',
#    'dhs',
#    'can',
#    'apply',
#    'for',
#    'social',
#    'security',
#    'number'],
#   '31': ['if', 'you', 'are', 'foreign', 'worker'],
#   '32': ['we',
#    'only',
#    'need',
#    'to',
#    'see',
#    'an',
#    'arrival',
#    'departure',
#    'record',
#    'or',
#    'admission',
#    'stamp',
#    'in',
#    'the',
#    'unexpired',
#    'foreign',
#    'passport',
#    'showing',
#    'class',
#    'of',
#    'admission',
#    'permitting',
#    'work'],
#   '33': ['some',
#    'foreign',
#    'workers',
#    'must',
#    'show',
#    'their',
#    'employment',
#    'authorization',
#    'document',
#    'ead',
#    'work',
#    'permit',
#    'from',
#    'dhs'],
#   '34': ['if',
#    'you',
#    'submit',
#    'evidence',
#    'of',
#    'lawful',
#    'work',
#    'authorized',
#    'status',
#    'for',
#    'your',
#    'child',
#    'along',
#    'with',
#    'evidence',
#    'of',
#    'name',
#    'change'],
#   '35': ['we',
#    'can',
#    'issue',
#    'your',
#    'child',
#    'corrected',
#    'card',
#    'with',
#    'his',
#    'or',
#    'her',
#    'new',
#    'name'],
#   '36': ['however'],
#   '37': ['if',
#    'we',
#    'assigned',
#    'your',
#    'child',
#    'social',
#    'security',
#    'number',
#    'for',
#    'non',
#    'work',
#    'purposes'],
#   '38': ['special', 'rules', 'apply'],
#   '39': ['if',
#    'your',
#    'child',
#    'is',
#    'not',
#    'authorized',
#    'to',
#    'work',
#    'by',
#    'dhs',
#    'we',
#    'will',
#    'change',
#    'your',
#    'child',
#    'name',
#    'on',
#    'our',
#    'records'],
#   '40': ['but', 'we', 'cannot', 'issue', 'corrected', 'card'],
#   '41': ['your',
#    'child',
#    'cannot',
#    'use',
#    'social',
#    'security',
#    'number',
#    'assigned',
#    'for',
#    'non',
#    'work',
#    'purposes',
#    'to',
#    'work'],
#   '42': ['if', 'your', 'child', 'does', 'use', 'it', 'to', 'work'],
#   '43': ['we', 'will', 'inform', 'dhs'],
#   '44': ['student'],
#   '45': ['if',
#    'you',
#    'are',
#    'an',
#    'student',
#    'and',
#    'eligible',
#    'to',
#    'work',
#    'on',
#    'campus'],
#   '46': ['you',
#    'must',
#    'provide',
#    'letter',
#    'from',
#    'your',
#    'designated',
#    'school',
#    'official',
#    'that'],
#   '47': ['identifies', 'you'],
#   '48': ['confirms', 'your', 'current', 'school', 'status'],
#   '49': ['and'],
#   '50': ['identifies',
#    'your',
#    'employer',
#    'and',
#    'the',
#    'type',
#    'of',
#    'work',
#    'you',
#    'are',
#    'or',
#    'will',
#    'be',
#    'doing'],
#   '51': ['we',
#    'also',
#    'need',
#    'to',
#    'see',
#    'evidence',
#    'of',
#    'that',
#    'employment',
#    'such',
#    'as',
#    'recent',
#    'pay',
#    'slip',
#    'or',
#    'letter',
#    'from',
#    'your',
#    'employer'],
#   '52': ['your', 'supervisor', 'must', 'sign', 'and', 'date', 'the', 'letter'],
#   '53': ['the', 'letter', 'must', 'describe'],
#   '54': ['your', 'job'],
#   '55': ['your', 'employment', 'start', 'date'],
#   '56': ['the',
#    'number',
#    'of',
#    'hours',
#    'you',
#    'are',
#    'or',
#    'will',
#    'be',
#    'working'],
#   '57': ['and'],
#   '58': ['your', 'supervisor', 'name', 'and', 'telephone', 'number'],
#   '59': ['if',
#    'you',
#    'are',
#    'an',
#    'student',
#    'authorized',
#    'to',
#    'work',
#    'in',
#    'curricular',
#    'practical',
#    'training',
#    'cpt'],
#   '60': ['you',
#    'must',
#    'provide',
#    'us',
#    'your',
#    'form',
#    'with',
#    'the',
#    'employment',
#    'page',
#    'completed',
#    'and',
#    'signed',
#    'by',
#    'your',
#    'designated',
#    'school',
#    'official'],
#   '61': ['if',
#    'you',
#    'are',
#    'an',
#    'student',
#    'and',
#    'have',
#    'work',
#    'permit',
#    'from',
#    'dhs'],
#   '62': ['you', 'must', 'present', 'it'],
#   '63': ['if',
#    'you',
#    'are',
#    'student',
#    'student',
#    'intern',
#    'or',
#    'international',
#    'visitor'],
#   '64': ['you', 'must', 'provide', 'letter', 'from', 'your', 'sponsor'],
#   '65': ['the',
#    'letter',
#    'should',
#    'be',
#    'on',
#    'sponsor',
#    'letterhead',
#    'with',
#    'an',
#    'original',
#    'signature',
#    'that',
#    'authorizes',
#    'your',
#    'employment'],
#   '66': ['name', 'change'],
#   '67': ['if',
#    'you',
#    'need',
#    'to',
#    'change',
#    'the',
#    'name',
#    'on',
#    'your',
#    'child',
#    'social',
#    'security',
#    'record'],
#   '68': ['you',
#    'must',
#    'show',
#    'us',
#    'proof',
#    'of',
#    'your',
#    'child',
#    'legal',
#    'name',
#    'change'],
#   '69': ['documents',
#    'social',
#    'security',
#    'may',
#    'accept',
#    'to',
#    'prove',
#    'your',
#    'child',
#    'legal',
#    'name',
#    'change',
#    'include'],
#   '70': ['final', 'adoption', 'decree', 'with', 'the', 'new', 'name'],
#   '71': ['court', 'order', 'approving', 'the', 'name', 'change'],
#   '72': ['if',
#    'the',
#    'document',
#    'you',
#    'provide',
#    'as',
#    'evidence',
#    'of',
#    'your',
#    'child',
#    'legal',
#    'name',
#    'change',
#    'does',
#    'not',
#    'give',
#    'us',
#    'enough',
#    'information',
#    'to',
#    'identify',
#    'your',
#    'child',
#    'in',
#    'our',
#    'records',
#    'or',
#    'if',
#    'you',
#    'changed',
#    'your',
#    'child',
#    'name',
#    'more',
#    'than',
#    'four',
#    'years',
#    'ago'],
#   '73': ['you',
#    'must',
#    'show',
#    'us',
#    'an',
#    'identity',
#    'document',
#    'in',
#    'your',
#    'child',
#    'prior',
#    'name',
#    'as',
#    'shown',
#    'in',
#    'our',
#    'records'],
#   '74': ['we',
#    'will',
#    'accept',
#    'an',
#    'identity',
#    'document',
#    'in',
#    'your',
#    'child',
#    'old',
#    'name',
#    'that',
#    'has',
#    'expired'],
#   '75': ['if',
#    'you',
#    'do',
#    'not',
#    'have',
#    'an',
#    'identity',
#    'document',
#    'in',
#    'your',
#    'child',
#    'prior',
#    'name'],
#   '76': ['we',
#    'may',
#    'accept',
#    'an',
#    'unexpired',
#    'identity',
#    'document',
#    'in',
#    'your',
#    'child',
#    'new',
#    'name',
#    'as',
#    'long',
#    'as',
#    'we',
#    'can',
#    'properly',
#    'establish',
#    'your',
#    'child',
#    'identity',
#    'in',
#    'our',
#    'records'],
#   '77': ['identity'],
#   '78': ['your', 'child'],
#   '79': ['social',
#    'security',
#    'will',
#    'ask',
#    'to',
#    'see',
#    'your',
#    'child',
#    'current',
#    'immigration',
#    'document',
#    'from',
#    'dhs'],
#   '80': ['acceptable', 'immigration', 'documents', 'include', 'your', 'child'],
#   '81': ['permanent', 'resident', 'card'],
#   '82': ['arrival',
#    'departure',
#    'record',
#    'with',
#    'unexpired',
#    'foreign',
#    'passport',
#    'or',
#    'admission',
#    'stamp',
#    'in',
#    'the',
#    'unexpired',
#    'foreign',
#    'passport'],
#   '83': ['or'],
#   '84': ['employment', 'authorization', 'document'],
#   '85': ['ead', 'work', 'permit', 'from', 'dhs'],
#   '86': ['you'],
#   '87': ['we', 'also', 'must', 'see', 'proof', 'of', 'your', 'identity'],
#   '88': ['an',
#    'acceptable',
#    'document',
#    'must',
#    'be',
#    'current',
#    'not',
#    'expired',
#    'and',
#    'show',
#    'your',
#    'name',
#    'identifying',
#    'information',
#    'date',
#    'of',
#    'birth',
#    'or',
#    'age',
#    'and',
#    'preferably',
#    'recent',
#    'photograph'],
#   '89': ['for', 'example'],
#   '90': ['as',
#    'proof',
#    'of',
#    'identity',
#    'social',
#    'security',
#    'must',
#    'see',
#    'your'],
#   '91': ['driver', 'license'],
#   '92': ['state', 'issued', 'non', 'driver', 'identification', 'card'],
#   '93': ['or'],
#   '94': ['passport'],
#   '95': ['if',
#    'you',
#    'do',
#    'not',
#    'have',
#    'one',
#    'of',
#    'these',
#    'specific',
#    'documents',
#    'or',
#    'you',
#    'cannot',
#    'get',
#    'replacement',
#    'for',
#    'one',
#    'of',
#    'them',
#    'within',
#    'days'],
#   '96': ['we', 'will', 'ask', 'to', 'see', 'other', 'documents'],
#   '97': ['any',
#    'documents',
#    'submitted',
#    'including',
#    'the',
#    'following',
#    'must',
#    'be',
#    'current',
#    'not',
#    'expired',
#    'and',
#    'show',
#    'your',
#    'name',
#    'identifying',
#    'information',
#    'date',
#    'of',
#    'birth',
#    'or',
#    'age',
#    'and',
#    'preferably',
#    'recent',
#    'photograph'],
#   '98': ['employee', 'identification', 'card'],
#   '99': ['school', 'identification', 'card'],
#   '100': ['health', 'insurance', 'card', 'not', 'medicare', 'card'],
#   '101': ['military', 'identification', 'card'],
#   '102': ['or'],
#   '103': ['doctor'],
#   '104': ['clinic', 'or', 'hospital', 'record'],
#   '105': ['if', 'you', 'are', 'not', 'citizen'],
#   '106': ['social',
#    'security',
#    'will',
#    'ask',
#    'to',
#    'see',
#    'your',
#    'current',
#    'immigration',
#    'document',
#    'from',
#    'dhs'],
#   '107': ['acceptable', 'immigration', 'documents', 'include', 'your'],
#   '108': ['form',
#    'includes',
#    'machine',
#    'readable',
#    'immigrant',
#    'visa',
#    'with',
#    'unexpired',
#    'foreign',
#    'passport'],
#   '109': ['or',
#    'admission',
#    'stamp',
#    'in',
#    'the',
#    'unexpired',
#    'foreign',
#    'passport'],
#   '110': ['or'],
#   '111': ['employment', 'authorization', 'document'],
#   '112': ['ead', 'work', 'permit', 'from', 'dhs'],
#   '113': ['note'],
#   '114': ['if', 'we', 'issue', 'your', 'child', 'new', 'card'],
#   '115': ['it',
#    'will',
#    'have',
#    'the',
#    'same',
#    'number',
#    'as',
#    'your',
#    'child',
#    'previous',
#    'card',
#    'but',
#    'will',
#    'show',
#    'new',
#    'name'],
#   '116': ['we',
#    'will',
#    'mail',
#    'your',
#    'child',
#    'card',
#    'as',
#    'soon',
#    'as',
#    'we',
#    'have',
#    'all',
#    'of',
#    'your',
#    'child',
#    'information',
#    'and',
#    'have',
#    'verified',
#    'your',
#    'child',
#    'immigration',
#    'documents']},
#  'How To Apply For VA Voc Rehab And Employment | Veterans Affairs#1_0': {'1': ['how',
#    'to',
#    'apply',
#    'for',
#    'va',
#    'voc',
#    'rehab',
#    'and',
#    'employment'],
#   '2': ['find',
#    'out',
#    'how',
#    'to',
#    'apply',
#    'for',
#    'va',
#    'voc',
#    'rehab',
#    'and',
#    'employment',
#    'also',
#    'known',
#    'as',
#    'vocational',
#    'rehabilitation',
#    'and',
#    'employment',
#    'vr',
#    'or',
#    'chapter',
#    'benefits'],
#   '3': ['how',
#    'do',
#    'apply',
#    'if',
#    'already',
#    'have',
#    'va',
#    'disability',
#    'rating'],
#   '4': ['sign', 'in', 'to', 'your', 'ebenefits', 'account'],
#   '5': ['select', 'apply'],
#   '6': ['click',
#    'vocational',
#    'rehabilitation',
#    'and',
#    'employment',
#    'benefits'],
#   '7': ['select',
#    'the',
#    'vocational',
#    'rehabilitation',
#    'and',
#    'employment',
#    'benefit',
#    'you',
#    're',
#    'applying',
#    'for'],
#   '8': ['if', 'you', 're', 'eligible'],
#   '9': ['we',
#    'll',
#    'invite',
#    'you',
#    'to',
#    'an',
#    'orientation',
#    'session',
#    'at',
#    'your',
#    'nearest',
#    'va',
#    'regional',
#    'benefit',
#    'office'],
#   '10': ['go', 'to', 'ebenefits', 'to', 'apply'],
#   '11': ['what',
#    'if',
#    'service',
#    'member',
#    'who',
#    'hasn',
#    'yet',
#    'received',
#    'service',
#    'connected',
#    'disability',
#    'rating'],
#   '12': ['you', 'don', 'need', 'to', 'wait', 'for', 'rating'],
#   '13': ['instead'],
#   '14': ['please',
#    'fill',
#    'out',
#    'va',
#    'vocational',
#    'rehabilitation',
#    'getting',
#    'ahead',
#    'after',
#    'you',
#    'get',
#    'out',
#    'va',
#    'form'],
#   '15': ['download', 'va', 'form', 'pdf'],
#   '16': ['you',
#    'may',
#    'be',
#    'eligible',
#    'for',
#    'vr',
#    'benefits',
#    'and',
#    'services',
#    'if',
#    'you',
#    're',
#    'in',
#    'at',
#    'least',
#    'one',
#    'of',
#    'the',
#    'below',
#    'situations'],
#   '17': ['at', 'least', 'one', 'of', 'these', 'must', 'be', 'true'],
#   '18': ['you', 're'],
#   '19': ['going',
#    'through',
#    'the',
#    'physical',
#    'evaluation',
#    'board',
#    'process',
#    'or'],
#   '20': ['expecting',
#    'an',
#    'other',
#    'than',
#    'dishonorable',
#    'discharge',
#    'and',
#    'have',
#    'va',
#    'memorandum',
#    'rating',
#    'of',
#    'or',
#    'more'],
#   '21': ['or'],
#   '22': ['entered',
#    'in',
#    'the',
#    'integrated',
#    'disability',
#    'evaluation',
#    'system',
#    'ides'],
#   '23': ['learn',
#    'more',
#    'about',
#    'accessing',
#    'vr',
#    'services',
#    'through',
#    'ides'],
#   '24': ['please', 'note'],
#   '25': ['severely',
#    'injured',
#    'active',
#    'duty',
#    'service',
#    'members',
#    'can',
#    'automatically',
#    'receive',
#    'vr',
#    'benefits',
#    'before',
#    'va',
#    'issues',
#    'disability',
#    'rating',
#    'because',
#    'of',
#    'sec'],
#   '26': ['of', 'the', 'national', 'defense', 'authorization', 'act', 'pl'],
#   '27': ['the',
#    'sunset',
#    'date',
#    'of',
#    'that',
#    'law',
#    'has',
#    'been',
#    'extended',
#    'to',
#    'september',
#    'through',
#    'sec'],
#   '28': ['of', 'public', 'law'],
#   '29': ['what', 'happens', 'after', 'apply'],
#   '30': ['after', 'you', 'apply'],
#   '31': ['we',
#    'll',
#    'schedule',
#    'meeting',
#    'for',
#    'you',
#    'with',
#    'vocational',
#    'rehabilitation',
#    'counselor',
#    'vrc',
#    'to',
#    'find',
#    'out',
#    'if',
#    'you',
#    'have',
#    'an',
#    'employment',
#    'handicap',
#    'and',
#    'if',
#    'you',
#    're',
#    'eligible',
#    'for',
#    'vr',
#    'benefits',
#    'and',
#    'services'],
#   '32': ['you',
#    'have',
#    'an',
#    'employment',
#    'handicap',
#    'if',
#    'your',
#    'service',
#    'connected',
#    'disability',
#    'limits',
#    'your',
#    'ability',
#    'to',
#    'prepare',
#    'for',
#    'obtain',
#    'and',
#    'maintain',
#    'suitable',
#    'employment',
#    'job',
#    'that',
#    'doesn',
#    'make',
#    'your',
#    'disability',
#    'worse',
#    'is',
#    'stable',
#    'and',
#    'matches',
#    'your',
#    'abilities',
#    'aptitudes',
#    'and',
#    'interests'],
#   '33': ['after', 'we', 'make', 'an', 'entitlement', 'decision'],
#   '34': ['you',
#    'and',
#    'your',
#    'counselor',
#    'will',
#    'work',
#    'together',
#    'to',
#    'develop',
#    'rehabilitation',
#    'plan'],
#   '35': ['this',
#    'plan',
#    'outlines',
#    'the',
#    'rehabilitation',
#    'and',
#    'other',
#    'services',
#    'that',
#    'vr',
#    'will',
#    'provide'],
#   '36': ['you',
#    'can',
#    'also',
#    'meet',
#    'with',
#    'vrcs',
#    'called',
#    'vetsuccess',
#    'on',
#    'campus',
#    'vsoc',
#    'counselors',
#    'at',
#    'schools',
#    'participating',
#    'in',
#    'the',
#    'vetsuccess',
#    'on',
#    'campus',
#    'vsoc',
#    'program'],
#   '37': ['learn', 'more', 'about', 'vetsuccess', 'on', 'campus'],
#   '38': ['what', 'included', 'in', 'rehabilitation', 'plan'],
#   '39': ['rehabilitation',
#    'plan',
#    'is',
#    'written',
#    'plan',
#    'that',
#    'outlines',
#    'the',
#    'resources',
#    'we',
#    'll',
#    'use',
#    'to',
#    'help',
#    'you',
#    'find',
#    'employment'],
#   '40': ['depending', 'on', 'your', 'situation'],
#   '41': ['your',
#    'vrc',
#    'will',
#    'work',
#    'with',
#    'you',
#    'to',
#    'choose',
#    'one',
#    'of',
#    'the',
#    'following',
#    'support',
#    'and',
#    'services',
#    'tracks',
#    'to',
#    'help',
#    'you',
#    'find',
#    'and',
#    'keep',
#    'job',
#    'and',
#    'live',
#    'as',
#    'independently',
#    'as',
#    'possible'],
#   '42': ['reemployment', 'with', 'former', 'employer'],
#   '43': ['job',
#    'placement',
#    'and',
#    'counseling',
#    'services',
#    'for',
#    'new',
#    'employment'],
#   '44': ['help', 'with', 'starting', 'your', 'own', 'business'],
#   '45': ['to',
#    'help',
#    'you',
#    'find',
#    'work',
#    'in',
#    'different',
#    'field',
#    'that',
#    'better',
#    'suits',
#    'your',
#    'abilities',
#    'and',
#    'interests'],
#   '46': ['long', 'term', 'training', 'or', 'services'],
#   '47': ['if', 'you', 'can', 'return', 'to', 'work', 'right', 'away'],
#   '48': ['independent', 'living', 'services'],
#   '49': ['what',
#    'happens',
#    'after',
#    'my',
#    'vrc',
#    'creates',
#    'my',
#    'rehabilitation',
#    'plan'],
#   '50': ['your',
#    'vrc',
#    'will',
#    'help',
#    'you',
#    'put',
#    'your',
#    'plan',
#    'into',
#    'action'],
#   '51': ['they',
#    'll',
#    'also',
#    'provide',
#    'ongoing',
#    'counseling',
#    'and',
#    'help',
#    'you',
#    'get',
#    'tutorial',
#    'assistance',
#    'job',
#    'training',
#    'work',
#    'readiness',
#    'support',
#    'and',
#    'medical',
#    'referrals']}}

# %% [markdown]
# ### training

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

models_for_doc = {}
for doc_id in tokenized_training_docs:
    tokenized_span_dic = tokenized_training_docs[doc_id]
    training_docs = [TaggedDocument(span, key) for key, span in tokenized_span_dic.items()]
    # Check how to fine tune the model https://radimrehurek.com/gensim/models/doc2vec.html
    model = Doc2Vec(training_docs, vector_size=10, window=4, min_count=1, workers=4, epochs=30)
    models_for_doc[doc_id] = model

len(models_for_doc)
# Out:
# 415

# %% [markdown]
# ### predict rc questions

# %%
predictions = []
references = []
for example in rc_dataset:
    question_ = example["question"]
    doc_id =example['title']
    # it does better if the user and agent string are left
    # question_ = question_.replace('user:', '')
    # question_ = question_.replace('agent:', '')

    #preprocess question in the same way
    test_doc = simple_preprocess(question_, deacc=True)
    #calculate vector using model for that document
    model = models_for_doc[doc_id]
    vector = model.infer_vector(test_doc)
    #find the most similar document (spans)
    sims = model.dv.most_similar([vector], topn=1)
    if sims[0][0] == '0':
        print(question_)
        print(doc_id)
        print(sims)
    # print(sims)
    # spans_dic = raw_training_text_per_doc[doc_id]
    # index_for_answer = sims[0][0]
    # most_likely_answer = list(spans_dic.values())[index_for_answer]
    # predicted_tag = list(spans_dic.keys())[index_for_answer]
    #
    # # most_likely_answer = training_docs[sims[0][0] - 1]
    # # most_likely_predicted_tag = most_likely_answer.tags
    # #find original text for tag
    # # most_likely_predicted_text = spans[most_likely_predicted_tag[0]-1]
    # print(f'Question: {question_}\n')
    # print(f'Predicted Answer tag {predicted_tag}: {most_likely_answer}\n')
    # print(f'Correct answer: {example["answers"]}\n')
    #
    # id_ = example["id"]
    # predictions.append(
    #     {'id': id_,
    #      'prediction_text':
    #          most_likely_answer,
    #      'no_answer_probability': 0.0
    #      }
    # )
    #
    # #just using their answers
    # references.append(
    #     {
    #         "id": id_,
    #         "answers": example["answers"],
    #     }
    # )

predictions[:5]
# Out:
# user:Hello, I forgot o update my address, can you help me with that?
# Top 5 DMV Mistakes and How to Avoid Them#3_0
# [('0', 0.9982489347457886)]
# user:I need to know how much is the fee for my vehicle.
# Commercial vehicle registration fees, vehicle use taxes and supplemental fees#3_0
# [('0', 0.9873241186141968)]
# user:What are the things that I need to organise before I am eligible to take my road test?
# Prepare for your road test#3_0
# [('0', 0.9988679885864258)]
# user:Can I send an appeal by mail?
# Appeal a TVB ticket conviction#1_0
# [('0', 0.9967803359031677)]
# user:I'm looking to appeal a conviction.
# Appeal a TVB ticket conviction#1_0
# [('0', 0.9387500286102295)]
# user:How do I get proof of ownership?
# Proof of ownership is not available#3_0
# [('0', 0.9965589046478271)]
# user:yes there is 	agent:is there a surviving spouse that wants to transfer ownership? 	user:no it won't 	agent:will the transfer be made according to the Estates , Powers & Trust Law of New York State? 	agent:Use this checklist to help you transfer the ownership when the vehicle owner is deceased PDF MV-843 	user:I need some deceased owner info for transfers
# Transfer ownership and acceptable proofs of ownership#3_0
# [('0', 0.9879569411277771)]
# user:what if there had been no surviving spouse? 	agent:okay, the spouse  must print the decedent s name in the Seller s Name Print in Full section on the back of the Title and sign their name in the Seller s Signature Section followed by the words as surviving Spouse 	user:yes there is 	agent:is there a surviving spouse that wants to transfer ownership? 	user:no it won't 	agent:will the transfer be made according to the Estates , Powers & Trust Law of New York State? 	agent:Use this checklist to help you transfer the ownership when the vehicle owner is deceased PDF MV-843 	user:I need some deceased owner info for transfers
# Transfer ownership and acceptable proofs of ownership#3_0
# [('0', 0.983894944190979)]
# user:what about cars and living trusts? 	agent:it would be disqualified 	user:what if there had been no surviving spouse? 	agent:okay, the spouse  must print the decedent s name in the Seller s Name Print in Full section on the back of the Title and sign their name in the Seller s Signature Section followed by the words as surviving Spouse 	user:yes there is 	agent:is there a surviving spouse that wants to transfer ownership? 	user:no it won't 	agent:will the transfer be made according to the Estates , Powers & Trust Law of New York State? 	agent:Use this checklist to help you transfer the ownership when the vehicle owner is deceased PDF MV-843 	user:I need some deceased owner info for transfers
# Transfer ownership and acceptable proofs of ownership#3_0
# [('0', 0.9815854430198669)]
# user:what proof do we need for trailers? 	agent:The owner and the settlor must complete Statement of Transaction- Sale or Gift of Motor Vehicle , Trailer , All - Terrain Vehicle ATV , Vessel Boat , or Snowmobile at NY State Department of Tax and Finance  	user:what about cars and living trusts? 	agent:it would be disqualified 	user:what if there had been no surviving spouse? 	agent:okay, the spouse  must print the decedent s name in the Seller s Name Print in Full section on the back of the Title and sign their name in the Seller s Signature Section followed by the words as surviving Spouse 	user:yes there is 	agent:is there a surviving spouse that wants to transfer ownership? 	user:no it won't 	agent:will the transfer be made according to the Estates , Powers & Trust Law of New York State? 	agent:Use this checklist to help you transfer the ownership when the vehicle owner is deceased PDF MV-843 	user:I need some deceased owner info for transfers
# Transfer ownership and acceptable proofs of ownership#3_0
# [('0', 0.9844852685928345)]
# user:I'm enquiring about theft
# ATVs: Information for Owners and Operators#3_0
# [('0', 0.9919323921203613)]
# user:I want to know about operating ATVs on private land
# ATVs: Information for Owners and Operators#3_0
# [('0', 0.9974585175514221)]
# user:Yes, that's correct. 	agent:Do you want to operate your ATV only on private lands? 	user:I want to know about operating ATVs on private land
# ATVs: Information for Owners and Operators#3_0
# [('0', 0.9976920485496521)]
# user:Can I personalize my plate?
# Learn about personalized plates#3_0
# [('0', 0.9406187534332275)]
# user:I want to know about the ignition interlock device.
# Leandra's Law & ignition interlock devices#3_0
# [('0', 0.9849128127098083)]
# user:I am looking at a used vehicle on your website and want to know what the reported mileage is?
# Let the Buyer be Aware#3_0
# [('0', 0.9967424869537354)]
# user:Hey there, i'm looking to renew a commercial driving license. Could you guide me a little on that?
# Renew a CDL#1_0
# [('0', 0.9951743483543396)]
# user:What happens if I fail the course?
# About online and alternative delivery method courses (I-PIRP/ADM)#3_0
# [('0', 0.9990597367286682)]
# user:how do i get a CDL
# Get a CDL#1_0
# [('0', 0.9884663224220276)]
# user:Hello, I would like you to help me how to apply?
# Open a dealership#3_0
# [('0', 0.9959814548492432)]
# user:Hey, Good morning. I recently had to go to a repair shop, but i'm having some issues, Is there something you can do about it?
# Know Your Rights in Auto Repair#3_0
# [('0', 0.9987057447433472)]
# user:xdfsgrg
# Know Your Rights in Auto Repair#3_0
# [('0', -0.10897166281938553)]
# user:I have questions about getting a military skills test waiver.
# Get a military skills test waiver#1_0
# [('0', 0.9064082503318787)]
# user:I need standard driving record info
# How to get my own driving record (abstract)#1_0
# [('0', 0.9904444813728333)]
# user:I'm not from New York and I need help getting a temporary snowmobile registration.
# Register a snowmobile#1_0
# [('0', 0.9992021918296814)]
# user:Hello I need information about Suspension Termination Fee Payment
# Pay suspension termination fee#1_0
# [('0', 0.9960825443267822)]
# user:sales tax info
# Sales tax information#3_0
# [('0', 0.7633517980575562)]
# user:Hi, can you tell me how can I request?
# Open a repair or body shop#3_0
# [('0', 0.9906890988349915)]
# user:How to Register an ATV
# Register an ATV#1_0
# [('0', 0.9924945831298828)]
# user:Hello, I would like to know more about replacing or transferring personalized plates.
# Replace or transfer personalized plates#1_0
# [('0', 0.9706450700759888)]
# user:Hello I need information about How to get a vehicle registration
# Get a vehicle registration or title record (abstract)#1_0
# [('0', 0.9876348376274109)]
# user:I need some information on paying for a driver responsibility assessment.
# Pay driver responsibility assessment#1_0
# [('0', 0.9981232285499573)]
# user:I need to get a corrected card for my son.
# Learn what documents you will need to get a Social Security Card | Social Security Administration#5_0
# [('0', 0.9988234043121338)]
# user:I need information about the corrected card for noncitizen children
# Learn what documents you will need to get a Social Security Card | Social Security Administration#6_0
# [('0', 0.9990879893302917)]
# user:I need to obtain a new card for my son, but he's not a citizen.
# Learn what documents you will need to get a Social Security Card | Social Security Administration#6_0
# [('0', 0.9971657395362854)]
# user:I need a replacement social security card for a noncitizen adult
# Learn what documents you will need to get a Social Security Card | Social Security Administration#16_0
# [('0', 0.9992658495903015)]
# user:I am not a citizen, how do I get a replacement card?
# Learn what documents you will need to get a Social Security Card | Social Security Administration#16_0
# [('0', 0.9917672872543335)]
# user:I need to get a card for my son who is not currently a citizen.
# Learn what documents you will need to get a Social Security Card | Social Security Administration#13_0
# [('0', 0.999160647392273)]
# user:I need to get my Social Security card for the very first time. I'm a noncitizen adult.
# Learn what documents you will need to get a Social Security Card | Social Security Administration#9_0
# [('0', 0.9982471466064453)]
# user:How do i get replacement card for a noncitizen child?
# Learn what documents you will need to get a Social Security Card | Social Security Administration#19_0
# [('0', 0.9976246953010559)]
# user:Just wanting to know about benefits for my husband
# Benefits Planner: Disability | Family Benefits | Social Security Administration#2_0
# [('0', 0.997244656085968)]
# user:What are disability benefits and how do I receive them?
# Disability Benefits | Social Security Administration#1_0
# [('0', 0.9977990388870239)]
# user:Yes, I do. 	agent:Are you currently receiving Social Security disability benefits? 	agent:Of course. I can tell you all you want about disability benefits. 	user:Hey, can you tell me something about disability benefits?
# Disability Benefits | Social Security Administration#1_0
# [('0', 0.9990352988243103)]
# user:Hello, do I need information on the documents to submit for disability benefits?
# Disability Benefits | Social Security Administration#2_0
# [('0', 0.9944149255752563)]
# user:Hello, do I need information on the documents to submit for disability benefits?
# Disability Benefits | Social Security Administration#2_0
# [('0', 0.9956566691398621)]
# user:I need to know how to colect social security under my spouse
# Benefits Planner: Retirement | Benefits For Your Spouse | Social Security Administration#1_0
# [('0', 0.9964861869812012)]
# user:I can't figure out the protection on my account.
# my Social Security | Security and Protection | Social Security Administration#1_0
# [('0', 0.9977202415466309)]
# user:Please, tell me some general information about direct depositing.
# Direct Deposit | Social Security Administration#2_0
# [('0', 0.9305048584938049)]
# user:Is direct depositied offered?
# Direct Deposit | Social Security Administration#1_0
# [('0', 0.9401794075965881)]
# user:How do i qualif?
# Benefits Planner: Disability | How You Qualify | Social Security Administration#2_0
# [('0', 0.9813423752784729)]
# user:Can you tell me if death benefits are available through Social Security?
# Benefits Planner: Survivors | If You Are The Survivor | Social Security Administration#2_0
# [('0', 0.9987388253211975)]
# user:How do I plan for disability?
# Benefits Planner: Disability | How You Qualify | Social Security Administration#1_0
# [('0', 0.9764191508293152)]
# user:yes 	agent:Do you have a disability? 	user:How do I plan for disability?
# Benefits Planner: Disability | How You Qualify | Social Security Administration#1_0
# [('0', 0.997428297996521)]
# user:Good afternoon, how are you?. Look, i 'm searching for info about medicare, what can you tell me?
# Medicare Benefits | Social Security Administration#2_0
# [('0', 0.9979789853096008)]
# user:I would like to learn more about Medicare benefits.
# Medicare Benefits | Social Security Administration#1_0
# [('0', 0.9983134269714355)]
# user:I want to plan for my retirement.
# Benefits Planner: Retirement | Applying for Medicare Only | Social Security Administration#1_0
# [('0', 0.9922435283660889)]
# user:Hey, I have some questions regarding the required amount of social security credits.
# Benefits Planner | Social Security Credits and Benefit Eligibility | SSA#1_0
# [('0', 0.9921420216560364)]
# user:Hello, do I need information about the steps to file a tax return?
# Benefits Planner: Retirement | Medicare Premiums | SSA#2_0
# [('0', 0.9972513318061829)]
# user:Hello, I would like to obtain information about Medicare monthly premiums for 2020
# Benefits Planner: Retirement | Medicare Premiums | SSA#2_0
# [('0', 0.9905112385749817)]
# user:Hello, can you please walk me through the steps of a child disability application?
# Apply For A Child (Under Age 18) | Disability Benefits | SSA#2_0
# [('0', 0.9834995865821838)]
# user:I'm looking for information.
# Careers And Employment | Veterans Affairs#1_0
# [('0', 0.9878610372543335)]
# user:Hi, there. I'm looking for information on housing assistance.
# VA Housing Assistance | Veterans Affairs#1_0
# [('0', 0.9970754384994507)]
# user:HI. I'm looking for information...
# Military Sexual Trauma (MST) | Veterans Affairs#1_0
# [('0', 0.9713407754898071)]
# user:I'm here about MST
# Military Sexual Trauma (MST) | Veterans Affairs#1_0
# [('0', 0.9951435923576355)]
# user:I applied for benefits and want some help
# After You Apply For Health Care Benefits | Veterans Affairs#1_0
# [('0', 0.995186448097229)]
# user:Hello there. I don't have VA health care benefits and I wanted to see if getting care was still an option.
# Substance Use Treatment For Veterans | Veterans Affairs#1_0
# [('0', 0.9990690350532532)]
# user:Hello there, I wanted to know how to get a VA home loan benefit.
# VA Housing Assistance | Veterans Affairs#2_0
# [('0', 0.9947513341903687)]
# user:
# Hello! I would like to get a welcome kit.
# Print Out Your VA Welcome Kit | Veterans Affairs#1_0
# [('0', 0.9930412769317627)]
# user:I would like to get information VA benefits for service members.
# VA Benefits For Service Members | Veterans Affairs#2_0
# [('0', 0.9900980591773987)]
# user:I need help with understanding my VA benefits.
# VA Benefits For Service Members | Veterans Affairs#1_0
# [('0', 0.9912053346633911)]
# user:Hello, how do I get an agent orange exam?
# VA Agent Orange Registry Exam | Veterans Affairs#1_0
# [('0', 0.9947556853294373)]
# user:Hey, glad i could reach you. You know, i think i have a problem with a veterans health card i requested, because it hasn't arrived yet, What happened there?
# Get A Veteran Health Identification Card (VHIC) | Veterans Affairs#1_0
# [('0', 0.9921264052391052)]
# user:Where will I go for VA health care?
# Where You'll Go For Care | Veterans Affairs#1_0
# [('0', 0.9978503584861755)]
# user:Hello there. How are you doing? I am looking for information about what happens after I submitted my application.
# Pre-Need Eligibility For Burial In A VA Cemetery | Veterans Affairs#1_0
# [('0', 0.9983059763908386)]
# user:Hello, I came here looking for more information about health care for veterans
# VA Health Care | Veterans Affairs#2_0
# [('0', 0.9955940842628479)]
# user:I want information on fully disabled or terminally ill policyholders
# Totally Disabled Or Terminally Ill Policyholders | Veterans Affairs#1_0
# [('0', 0.9966064095497131)]
# user:If I have a disability due to the VR&E Self-Employment Pathway, how can you help me?
# VR&E Self-Employment Track | Veterans Affairs#1_0
# [('0', 0.9983842372894287)]
# user:How Group Life Insurance for Veterans (VGLI) works
# Veterans’ Group Life Insurance (VGLI) | Veterans Affairs#1_0
# [('0', 0.9922240376472473)]
# user:How do I access VA nursing home services?
# VA Nursing Homes And Assisted Living | Veterans Affairs#1_0
# [('0', 0.9949319958686829)]
# user:hi i need help about veterans identification cards
# Types Of Veteran ID Cards | Veterans Affairs#1_0
# [('0', 0.9941926002502441)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/tb/kxdncxw16gx7p6y4hsgc0y540000gn/T/ipykernel_31920/2814084901.py in <module>
#      11     test_doc = simple_preprocess(question_, deacc=True)
#      12     #calculate vector using model for that document
# ---> 13     model = models_for_doc[doc_id]
#      14     vector = model.infer_vector(test_doc)
#      15     #find the most similar document (spans)
#
# KeyboardInterrupt:

# %%
spans = raw_training_text_per_doc['Top 5 DMV Mistakes and How to Avoid Them#3_0']
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/tb/kxdncxw16gx7p6y4hsgc0y540000gn/T/ipykernel_31920/2938224291.py in <module>
# ----> 1 spans = raw_training_text_per_doc['Top 5 DMV Mistakes and How to Avoid Them#3_0']
#
# /var/folders/tb/kxdncxw16gx7p6y4hsgc0y540000gn/T/ipykernel_31920/2938224291.py in <module>
# ----> 1 spans = raw_training_text_per_doc['Top 5 DMV Mistakes and How to Avoid Them#3_0']
#
# _pydevd_bundle/pydevd_cython_darwin_39_64.pyx in _pydevd_bundle.pydevd_cython_darwin_39_64.SafeCallWrapper.__call__()
#
# _pydevd_bundle/pydevd_cython_darwin_39_64.pyx in _pydevd_bundle.pydevd_cython_darwin_39_64.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle/pydevd_cython_darwin_39_64.pyx in _pydevd_bundle.pydevd_cython_darwin_39_64.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle/pydevd_cython_darwin_39_64.pyx in _pydevd_bundle.pydevd_cython_darwin_39_64.PyDBFrame.trace_dispatch()
#
# _pydevd_bundle/pydevd_cython_darwin_39_64.pyx in _pydevd_bundle.pydevd_cython_darwin_39_64.PyDBFrame.do_wait_suspend()
#
# ~/Library/Application Support/JetBrains/Toolbox/apps/DataSpell/ch-0/213.5744.170/DataSpell 2021.3.app/Contents/plugins/python-ce/helpers/pydev/pydevd.py in do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1145
#    1146         with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1147             self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#    1148
#    1149     def _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread):
#
# ~/Library/Application Support/JetBrains/Toolbox/apps/DataSpell/ch-0/213.5744.170/DataSpell 2021.3.app/Contents/plugins/python-ce/helpers/pydev/pydevd.py in _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1160
#    1161                 self.process_internal_commands()
# -> 1162                 time.sleep(0.01)
#    1163
#    1164         self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#
# KeyboardInterrupt:

# %% [markdown]
# ### evaluate

# %%
from datasets import load_metric

print(f'Number of question in train dataset {rc_dataset.shape[0]}')
metric = load_metric("squad_v2")
metric.add_batch(predictions=predictions, references=references)
final_score = metric.compute()
final_score
# Out:
# Number of question in train dataset 20431
# {'exact': 0.783123684596936,
#  'f1': 17.21500881285785,
#  'total': 20431,
#  'HasAns_exact': 0.783123684596936,
#  'HasAns_f1': 17.21500881285785,
#  'HasAns_total': 20431,
#  'best_exact': 0.783123684596936,
#  'best_exact_thresh': 0.0,
#  'best_f1': 17.21500881285785,
#  'best_f1_thresh': 0.0}

# %% [markdown]
# ### How does this compare to guessing at random?

# %%
import random

random_predictions = []
random_references = []
for example in rc_dataset:
    question_ = example["question"]
    doc_id =example['title']

    #pick a random text from the document
    texts = raw_training_text_per_doc[doc_id]
    most_likely_answer = texts[random.randint(0, len(texts)-1)]

    id_ = example["id"]
    random_predictions.append(
        {'id': id_,
         'prediction_text':
             most_likely_answer,
         'no_answer_probability': 0.0
         }
    )

    #just using their answers
    random_references.append(
        {
            "id": id_,
            "answers": example["answers"],
        }
    )

random_predictions[:3]
# Out:
# [{'id': '9f44c1539efe6f7e79b02eb1b413aa43_1',
#   'prediction_text': 'Many DMV customers make easily avoidable mistakes that cause them significant problems, including encounters with law enforcement and impounded vehicles. Because we see customers make these mistakes over and over again , we are issuing this list of the top five DMV mistakes and how to avoid them. ',
#   'no_answer_probability': 0.0},
#  {'id': '9f44c1539efe6f7e79b02eb1b413aa43_3',
#   'prediction_text': '\n\n2. Leaving the State Without Notifying DMV \n',
#   'no_answer_probability': 0.0},
#  {'id': '9f44c1539efe6f7e79b02eb1b413aa43_5',
#   'prediction_text': 'It is not sufficient to only: write your new address on the back of your old license; tell the United States Postal Service; or inform the police officer writing you a ticket. If you fail to keep your address current , you will miss a suspension order and may be charged with operating an unregistered vehicle and/or aggravated unlicensed operation, both misdemeanors. This really happens , but the good news is this is a problem that is easily avoidable. ',
#   'no_answer_probability': 0.0}]

# %%
print(f'Results for random text predictions for each question')
metric = load_metric("squad_v2")
metric.add_batch(predictions=random_p   redictions, references=random_references)
final_score = metric.compute()
final_score
# Out:
# Results for random text predictions for each question
# {'exact': 1.5907199843375264,
#  'f1': 14.745765602471895,
#  'total': 20431,
#  'HasAns_exact': 1.5907199843375264,
#  'HasAns_f1': 14.745765602471895,
#  'HasAns_total': 20431,
#  'best_exact': 1.5907199843375264,
#  'best_exact_thresh': 0.0,
#  'best_f1': 14.745765602471895,
#  'best_f1_thresh': 0.0}

# %% [markdown]
# ### Results for validation part of rc dataset

# %%
rc_validation_dataset = load_dataset(
    "doc2dial",
    name="doc2dial_rc",
    split="validation",
    ignore_verifications=True,
    cache_dir=cache_dir,
)
# Out:
# Reusing dataset doc2dial (./data_cache_doc2vec_solution_notebook/doc2dial/doc2dial_rc/1.0.1/765cb4d9af421b599d910080fd61b4a43440c1232693876470ef3245daa5fa4c)

# %%
predictions = []
references = []
print(f'Number of question in train dataset {rc_validation_dataset.shape[0]}')

for example in rc_validation_dataset:
    question_ = example["question"]
    doc_id =example['title']
    # it does better if the user and agent string are left
    # question_ = question_.replace('user:', '')
    # question_ = question_.replace('agent:', '')

    #preprocess question in the same way
    test_doc = simple_preprocess(question_, deacc=True)
    #calculate vector using model for that document
    model = models_for_doc[doc_id]
    vector = model.infer_vector(test_doc)
    #find the most similar document (spans)
    sims = model.dv.most_similar([vector], topn=1)
    most_likely_answer = raw_training_text_per_doc[doc_id][sims[0][0]]
    # most_likely_answer = training_docs[sims[0][0] - 1]
    # most_likely_predicted_tag = most_likely_answer.tags
    #find original text for tag
    # most_likely_predicted_text = spans[most_likely_predicted_tag[0]-1]
    # print(f': {most_likely_answer.words}\n')
    # print(f'Predicted Answer: {most_likely_answer}\n')

    id_ = example["id"]
    predictions.append(
        {'id': id_,
         'prediction_text':
             most_likely_answer,
         'no_answer_probability': 0.0
         }
    )

    #just using their answers
    references.append(
        {
            "id": id_,
            "answers": example["answers"],
        }
    )

predictions[:5]
# Out:
# Number of question in train dataset 3972
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/tb/kxdncxw16gx7p6y4hsgc0y540000gn/T/ipykernel_51203/723857626.py in <module>
#      13     test_doc = simple_preprocess(question_, deacc=True)
#      14     #calculate vector using model for that document
# ---> 15     model = models_for_doc[doc_id]
#      16     vector = model.infer_vector(test_doc)
#      17     #find the most similar document (spans)
#
# KeyError: 'About New York State Inspections#3_0'

# %% [markdown]
# ### Questions:
# - Given that we don't have all the documents to train does that make sense for a Doc2Vec approach or does it make sense
# to create a model per document?
